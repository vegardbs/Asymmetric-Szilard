# %%
import numpy as np
from numpy import pi
import pandas as pd
import random
import os
from qutip import *
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization
from keras.optimizers import Adam
from collections import deque
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from keras import backend as K


# %matplotlib inline

# %% [markdown]
# # DQL optimization of asymmetric Szilard engine
# This program uses Deep Q-Learning, to find protocols which split the quantum wavefunction of an asymmetric Szilard engine in half.

# %% [markdown]
# # Define environment

# %%
class Szilard_env:
    
    def __init__(self):

        self.max_lvl = 4
        
        self.viewer = None
        self.action_space = np.array([-1024,-512,-256,-128,-64,-32,-16,-8,-4,-2,0,2,4,8,16,32,64,128,256,512,1024])*10
        self.observation_space = np.array([0,0])
        
        self.max_alfa = 2000.0
        
        self.t_max = 5
        self.N_alfa = 50
        self.alfa_dt = self.t_max/self.N_alfa
        
        self.sigma1 = 0.05    # smaller gives more punishment for excitations
        self.sigma2 = 0.1
        
        self.best_protocol = [None]*self.N_alfa
        self.protocol = [None]*self.N_alfa
        self.best_reward = 0
        self.scores = []
        
        self.interp_energies = []
        self.interp_overlaps = []
        k = 0
        
        self.N_asymmetries = 6
        self.asymmetries = []
        
        for n in range (self.N_asymmetries):
            asymmetry = round(0.53 + 0.002*n,3)
            self.asymmetries.append(asymmetry)
            energy, overlap = self.interp_generator(asymmetry)
            self.interp_energies.append(energy)
            self.interp_overlaps.append(overlap)
        
        ## Here we can change the reward distribution to favour certain asymmetries
        
        #r_min  = 0.50
        #N_0 = -self.N_asymmetries/np.log(r_min)
        #x = np.array([n for n in range (self.N_asymmetries)])
        #self.reward_distribution = np.exp(-x/N_0)
        self.reward_distribution = np.ones(self.N_asymmetries)
            
    ## Interpolate data files to calculate eigenstates of the single-particle-box.    
    def interp_generator(self,a):
    
        max_lvl = 4 

        tab_alfa = np.loadtxt('/home/vegard/Split-wavefunction/data/alfa/alfa_a_' + "{:.3f}".format(a) + '.txt', delimiter = ',')        
        energies = np.loadtxt('/home/vegard/Split-wavefunction/data/energies/Energies_a_' + "{:.3f}".format(a) + '.txt', delimiter = ',')
        overlap = np.loadtxt('/home/vegard/Split-wavefunction/data/overlap/overlap_a_' + "{:.3f}".format(a)+ '.txt', delimiter = ',')

        overlap = np.reshape(overlap, [max_lvl,max_lvl,5001], order = 'F')

        interp_energy = [None]*max_lvl

        for n in range(max_lvl):
            f = interp1d(tab_alfa,energies[:,n], kind = 'cubic')
            interp_energy[n] = f

        interp_overlap = [[0] * max_lvl for i in range(max_lvl)]

        for n in range(max_lvl):
            for m in range(max_lvl):
                interp_overlap[n][m] = interp1d(tab_alfa,overlap[n,m,:], kind = 'cubic')

        return interp_energy, interp_overlap
    
    ## Interpolate the discrete protocol obtained from the agent at the end of each episode, and calculate the reward.
    def interp_reward(self, N_t):

        time_interp = np.array([ n*self.alfa_dt for n in range (self.N_alfa+1) ])
        
        alfa_interp = interp1d( time_interp,self.protocol, kind = 'cubic')
      
        time = np.linspace(0,self.t_max,N_t)
        alfa = alfa_interp(time)
        alfa = np.clip(alfa, 0, 5000)
    
        dt = time[1]-time[0]
        max_lvl = self.max_lvl
 
        E = []
        for t in range(N_t):
            E.append([self.interp_energy[n](alfa[t]) for n in range(max_lvl)])
        E = np.array(E)
        
        phi = []
        for t in range(N_t):
                integral = [np.trapz(x=time[0:t+1], y= E[0:t+1,n]) for n in range(max_lvl)]
                phi.append(integral)  
        phi = np.array(phi)   

        def interaction_int(n, alfa_in, f = []):
            test = sum([self.interp_overlap[n][m](abs(alfa_in))*np.exp(1j*(phi[t,n] - phi[t,m]) )*f[m] for m in range(max_lvl) if m != n ])*dalfa
            return test

        C = np.array([ 0 for n in range(max_lvl) ])
        C[0] = 1
        C_new = np.array( [ 0 for n in range(max_lvl) ])
        C_t = []
        C_t.append(C)

        for t in range(N_t -1):
            
            dalfa = (alfa[t+1] - alfa[t])/dt

            k1 = np.array([dt*interaction_int(n, alfa[t], C ) for n in range(max_lvl)])
            k2 = np.array([dt*interaction_int(n, alfa[t]+ dalfa*dt/2, C + k1/2 ) for n in range(max_lvl)])
            k3 = np.array([dt*interaction_int(n, alfa[t]+ dalfa*dt/2, C + k2/2 ) for n in range(max_lvl)])
            k4 = np.array([dt*interaction_int(n, alfa[t]+ dalfa*dt, C + k3) for n in range(max_lvl)])

            C_new = C + (k1 + 2*k2 + 2*k3 + k4)/6

            C = C_new

            C_t.append(C)

        c1 = abs(C[0])**2
        c2 = abs(C[1])**2
        
        reward = np.exp( -((c1 + c2 - 1))**2/self.sigma1 - ((c1 - c2))**2/self.sigma2 )
        
        #reward = - ((c1 + c2 - 1))**2/self.sigma1 - ((c1 - c2))**2/self.sigma2 

        #leakage = sum( abs(C[n])**2 for n in range(2,max_lvl) )
        #reward = np.exp( -((c1-0.5)**2 + (c2-0.5)**2)/(sigma))
        
        #print("Normalization_int: {}" .format(sum(abs(C)**2)))
        #print(abs(C)**2)
        #plt.plot(alfa(time),abs(np.array(C_t))**2)
        #plt.plot(time,abs(alfa(time)))
        
        return reward   

    ## Reset initial state after every episode     
    def reset(self):

        self.r = random.randrange(self.N_asymmetries)
        self.interp_energy = self.interp_energies[self.r]
        self.interp_overlap = self.interp_overlaps[self.r]
        
        self.time = 0.0
        self.alfa = 0.0
        self.steps = 0
        
        self.protocol = []
        self.protocol.append(0)
        self.action_sequence = []

        self.cum_reward = 0.0
                
        self.state =  [self.alfa/self.max_alfa] + [self.time/self.t_max]
        
        return np.array(self.state)       
    
    ## Take one step, and give reward as feedback.
    def step(self, action): 
        
        self.action_sequence.append(action)
        self.time += self.alfa_dt
        self.dalfa = self.action_space[action]
                
        self.new_alfa = self.alfa + self.dalfa*self.alfa_dt
        
        if self.new_alfa < 0.0:
            reward = -10
        elif self.new_alfa > self.max_alfa:
            reward = -10
        else:
            reward = 0

        self.new_alfa = np.clip(self.new_alfa, 0.0, self.max_alfa)
        
        self.steps += 1     
        self.protocol.append(self.new_alfa)
 
    
        self.alfa = self.new_alfa

        next_state = [self.alfa/self.max_alfa] + [self.time/self.t_max]

        
        if self.steps == self.N_alfa:
            
            N_t = 1000
            reward += 100*self.interp_reward(N_t)*self.reward_distribution[self.r]            
            done = True            
            #if  reward > self.best_reward:
             #   self.best_protocol = self.protocol
             #   self.best_reward = reward
                #print('REWARD: {}'.format(reward))
        else:
            done = False
         
        
        self.cum_reward += reward
        
        if done == True:
            
            self.scores.append(self.cum_reward)
        
        return np.array(next_state), reward, done, {}

# %% [markdown]
# # Define agent

# %%
class DQNAgent:
    
    def __init__(self, state_size, action_size):
        
        self.state_size = state_size
        self.action_size = action_size
        
        self.memory = deque(maxlen = 50000)
        
        self.gamma = 1.0
        
        self.epsilon = 1.0
        self.epsilon_decay = 0.99995
        self.epsilon_min = 0.01
        
        self.learning_rate = 0.001        
        
        self.model = self._build_model()
        self.target_model = self._build_model()
        
    def _build_model(self):
        
        model = Sequential()
        
        model.add(Dense(24, input_dim = self.state_size, activation = 'relu'))
        
        model.add(Dense(48, activation = 'relu'))
        
        model.add(Dense(24, activation = 'relu'))

        model.add(Dense(self.action_size, activation = 'linear'))
        
        model.compile(loss='mse', optimizer = Adam(lr = self.learning_rate))
        
        return model
    
    
    def remember(self, state, action, reward, next_state, done):
        
        self.memory.append((state, action, reward, next_state, done))
        
    def act(self,state):
        
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        act_values = self.model.predict(state)
        return np.argmax(act_values[0])
    
    def replay(self, batch_size):
        
        
        minibatch = random.sample(self.memory, batch_size)
        

        for state, action, reward, next_state, done in minibatch:
            
            target = self.target_model.predict(state)
            
            if done:
                target[0][action] = reward
                
            else:
                Q_future = max(self.target_model.predict(next_state)[0])
                target[0][action] = reward + Q_future*self.gamma
                
            self.model.fit(state, target, epochs = 1, verbose = 0)    
    
    def load(self, name):
        self.model.load_weights(name)
        
    def save(self,name):
        self.model.save_weights(name)

# %% [markdown]
# # Set Parameters

# %%
env = Szilard_env()
state_size = env.observation_space.shape[0]
action_size = env.action_space.shape[0]
print('State size: {}'.format(state_size))
print('Action size: {}'.format(action_size))

batch_size = 32
n_episodes = 40000
tau = 1e-3

agent = DQNAgent(state_size, action_size)
agent.epsilon_decay = (0.05)**(1/n_episodes)
agent.memory = deque(maxlen = 200000)

score = [None]*n_episodes

output_dir = 'model_output/Model_6/'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
print("Training on {} asymmetries in the range : {}".format(env.N_asymmetries,env.asymmetries))
print("Available actions: \n{}".format(env.action_space))
print("T_max = {}, Number of steps = {}, dt = {}".format(env.t_max, env.N_alfa, env.alfa_dt))
print("Hyperparameters: memorysize = {}, tau = {}, batch_size = {}".format(len(agent.memory),tau, batch_size))
print("Total number of experiences = {}".format(env.N_alfa*n_episodes))
# Out:
# State size: 2
# Action size: 21
# Training on 6 asymmetries in the range : [0.53, 0.532, 0.534, 0.536, 0.538, 0.54]
# Available actions:
# [-10240  -5120  -2560  -1280   -640   -320   -160    -80    -40    -20
#       0     20     40     80    160    320    640   1280   2560   5120
#   10240]
# T_max = 5, Number of steps = 50, dt = 0.1
# Hyperparameters: memorysize = 0, tau = 0.001, batch_size = 32
# Total number of experiences = 2000000

# %% [markdown]
# # Interact with environment

# %%
done = False

for e in range(n_episodes):
    
    state = env.reset()
    state = np.reshape(state, [1,state_size])
    
    for t in range(1000):
        
        action = agent.act(state)
        
        next_state, reward, done, _ = env.step(action)
                
        next_state = np.reshape(next_state, [1,state_size])
        
        agent.remember(state, action, reward, next_state, done)
        
        state = next_state
        
        if done:
            print('episode: {}/{}, score: {:.3}, epsilon: {:.2}'.format(e,n_episodes, env.cum_reward, agent.epsilon))
            score[e] = env.cum_reward
            break
        
        if len(agent.memory) > batch_size:
            agent.replay(batch_size)

            target_weights = np.array(agent.target_model.get_weights())
            current_weights = np.array(agent.model.get_weights())

            agent.target_model.set_weights(current_weights*tau + target_weights*(1-tau))
        
    if agent.epsilon > agent.epsilon_min:
        agent.epsilon *= agent.epsilon_decay
    
    if e % 100 == 0:
        agent.save(output_dir + "weights_" + "{:04d}".format(e) + ".hdf5")
# Out:
# episode: 0/40000, score: -18.4, epsilon: 1.0
# episode: 1/40000, score: -68.1, epsilon: 1.0
# episode: 2/40000, score: -44.2, epsilon: 1.0
# episode: 3/40000, score: -1.1e+02, epsilon: 1.0
# episode: 4/40000, score: -59.6, epsilon: 1.0
# episode: 5/40000, score: -1.5e+02, epsilon: 1.0
# episode: 6/40000, score: -1.6e+02, epsilon: 1.0
# episode: 7/40000, score: -81.2, epsilon: 1.0
# episode: 8/40000, score: -56.1, epsilon: 1.0
# episode: 9/40000, score: -1.5e+02, epsilon: 1.0
# episode: 10/40000, score: -20.0, epsilon: 1.0
# episode: 11/40000, score: -1.9e+02, epsilon: 1.0
# episode: 12/40000, score: -37.2, epsilon: 1.0
# episode: 13/40000, score: 36.2, epsilon: 1.0
# episode: 14/40000, score: 10.5, epsilon: 1.0
# episode: 15/40000, score: -1.4e+02, epsilon: 1.0
# episode: 16/40000, score: -37.3, epsilon: 1.0
# episode: 17/40000, score: -1.6e+02, epsilon: 1.0
# episode: 18/40000, score: -1.1e+02, epsilon: 1.0
# episode: 19/40000, score: -89.4, epsilon: 1.0
# episode: 20/40000, score: -77.0, epsilon: 1.0
# episode: 21/40000, score: -69.8, epsilon: 1.0
# episode: 22/40000, score: -50.1, epsilon: 1.0
# episode: 23/40000, score: -1.6e+02, epsilon: 1.0
# episode: 24/40000, score: -94.0, epsilon: 1.0
# episode: 25/40000, score: -1.56e+02, epsilon: 1.0
# episode: 26/40000, score: -1.26e+02, epsilon: 1.0
# episode: 27/40000, score: -1.29e+02, epsilon: 1.0
# episode: 28/40000, score: -79.6, epsilon: 1.0
# episode: 29/40000, score: -1.12e+02, epsilon: 1.0
# episode: 30/40000, score: -29.9, epsilon: 1.0
# episode: 31/40000, score: -60.0, epsilon: 1.0
# episode: 32/40000, score: -2e+02, epsilon: 1.0
# episode: 33/40000, score: -1.1e+02, epsilon: 1.0
# episode: 34/40000, score: -1.38e+02, epsilon: 1.0
# episode: 35/40000, score: -1.8e+02, epsilon: 1.0
# episode: 36/40000, score: -1.5e+02, epsilon: 1.0
# episode: 37/40000, score: -1.8e+02, epsilon: 1.0
# episode: 38/40000, score: -59.1, epsilon: 1.0
# episode: 39/40000, score: -79.7, epsilon: 1.0
# episode: 40/40000, score: -1.1e+02, epsilon: 1.0
# episode: 41/40000, score: -1.18e+02, epsilon: 1.0
# episode: 42/40000, score: -99.7, epsilon: 1.0
# episode: 43/40000, score: -56.9, epsilon: 1.0
# episode: 44/40000, score: -1.26e+02, epsilon: 1.0
# episode: 45/40000, score: -30.0, epsilon: 1.0
# episode: 46/40000, score: -16.2, epsilon: 1.0
# episode: 47/40000, score: -1e+02, epsilon: 1.0
# episode: 48/40000, score: -56.1, epsilon: 1.0
# episode: 49/40000, score: -23.8, epsilon: 1.0
# episode: 50/40000, score: -80.0, epsilon: 1.0
# episode: 51/40000, score: -9.95, epsilon: 1.0
# episode: 52/40000, score: -1.06e+02, epsilon: 1.0
# episode: 53/40000, score: -6.06, epsilon: 1.0
# episode: 54/40000, score: -1.6e+02, epsilon: 1.0
# episode: 55/40000, score: -19.8, epsilon: 1.0
# episode: 56/40000, score: -1.6e+02, epsilon: 1.0
# episode: 57/40000, score: -89.5, epsilon: 1.0
# episode: 58/40000, score: -50.0, epsilon: 1.0
# episode: 59/40000, score: -1.69e+02, epsilon: 1.0
# episode: 60/40000, score: -1.1e+02, epsilon: 1.0
# episode: 61/40000, score: 13.2, epsilon: 1.0
# episode: 62/40000, score: -1.41e+02, epsilon: 1.0
# episode: 63/40000, score: -76.7, epsilon: 1.0
# episode: 64/40000, score: -53.2, epsilon: 1.0
# episode: 65/40000, score: -80.0, epsilon: 1.0
# episode: 66/40000, score: -69.8, epsilon: 1.0
# episode: 67/40000, score: -1.07e+02, epsilon: 0.99
# episode: 68/40000, score: -39.5, epsilon: 0.99
# episode: 69/40000, score: 81.6, epsilon: 0.99
# episode: 70/40000, score: -59.7, epsilon: 0.99
# episode: 71/40000, score: -97.4, epsilon: 0.99
# episode: 72/40000, score: -79.7, epsilon: 0.99
# episode: 73/40000, score: -1.47e+02, epsilon: 0.99
# episode: 74/40000, score: -1.2e+02, epsilon: 0.99
# episode: 75/40000, score: -89.7, epsilon: 0.99
# episode: 76/40000, score: -80.0, epsilon: 0.99
# episode: 77/40000, score: -1.04e+02, epsilon: 0.99
# episode: 78/40000, score: -80.0, epsilon: 0.99
# episode: 79/40000, score: -67.7, epsilon: 0.99
# episode: 80/40000, score: -1.07e+02, epsilon: 0.99
# episode: 81/40000, score: -57.2, epsilon: 0.99
# episode: 82/40000, score: -1.19e+02, epsilon: 0.99
# episode: 83/40000, score: -1.4e+02, epsilon: 0.99
# episode: 84/40000, score: -12.9, epsilon: 0.99
# episode: 85/40000, score: -1.2e+02, epsilon: 0.99
# episode: 86/40000, score: -1.19e+02, epsilon: 0.99
# episode: 87/40000, score: -59.7, epsilon: 0.99
# episode: 88/40000, score: -78.0, epsilon: 0.99
# episode: 89/40000, score: -50.0, epsilon: 0.99
# episode: 90/40000, score: -1.2e+02, epsilon: 0.99
# episode: 91/40000, score: -31.7, epsilon: 0.99
# episode: 92/40000, score: -43.3, epsilon: 0.99
# episode: 93/40000, score: 71.3, epsilon: 0.99
# episode: 94/40000, score: -1.2e+02, epsilon: 0.99
# episode: 95/40000, score: 4.04, epsilon: 0.99
# episode: 96/40000, score: -1.19e+02, epsilon: 0.99
# episode: 97/40000, score: 70.4, epsilon: 0.99
# episode: 98/40000, score: 43.3, epsilon: 0.99
# episode: 99/40000, score: -99.5, epsilon: 0.99
# episode: 100/40000, score: -1.3e+02, epsilon: 0.99
# episode: 101/40000, score: -1.5e+02, epsilon: 0.99
# episode: 102/40000, score: -1.26e+02, epsilon: 0.99
# episode: 103/40000, score: -9.73, epsilon: 0.99
# episode: 104/40000, score: -79.7, epsilon: 0.99
# episode: 105/40000, score: -1.08e+02, epsilon: 0.99
# episode: 106/40000, score: -80.0, epsilon: 0.99
# episode: 107/40000, score: -70.0, epsilon: 0.99
# episode: 108/40000, score: -1.28e+02, epsilon: 0.99
# episode: 109/40000, score: -79.4, epsilon: 0.99
# episode: 110/40000, score: -25.5, epsilon: 0.99
# episode: 111/40000, score: -1.4e+02, epsilon: 0.99
# episode: 112/40000, score: -1.17e+02, epsilon: 0.99
# episode: 113/40000, score: -1.2e+02, epsilon: 0.99
# episode: 114/40000, score: -90.0, epsilon: 0.99
# episode: 115/40000, score: -1.6e+02, epsilon: 0.99
# episode: 116/40000, score: -2.49e+02, epsilon: 0.99
# episode: 117/40000, score: -1.79e+02, epsilon: 0.99
# episode: 118/40000, score: -89.7, epsilon: 0.99
# episode: 119/40000, score: -40.0, epsilon: 0.99
# episode: 120/40000, score: -1.2e+02, epsilon: 0.99
# episode: 121/40000, score: -1.61e+02, epsilon: 0.99
# episode: 122/40000, score: -1.1e+02, epsilon: 0.99
# episode: 123/40000, score: -1.7e+02, epsilon: 0.99
# episode: 124/40000, score: -59.7, epsilon: 0.99
# episode: 125/40000, score: -1.65e+02, epsilon: 0.99
# episode: 126/40000, score: -1e+02, epsilon: 0.99
# episode: 127/40000, score: -1.27e+02, epsilon: 0.99
# episode: 128/40000, score: -93.7, epsilon: 0.99
# episode: 129/40000, score: -98.7, epsilon: 0.99
# episode: 130/40000, score: -1.18e+02, epsilon: 0.99
# episode: 131/40000, score: -1.7e+02, epsilon: 0.99
# episode: 132/40000, score: -38.0, epsilon: 0.99
# episode: 133/40000, score: 38.1, epsilon: 0.99
# episode: 134/40000, score: -1.02e+02, epsilon: 0.99
# episode: 135/40000, score: -59.8, epsilon: 0.99
# episode: 136/40000, score: -1.58e+02, epsilon: 0.99
# episode: 137/40000, score: -90.0, epsilon: 0.99
# episode: 138/40000, score: -39.9, epsilon: 0.99
# episode: 139/40000, score: -98.6, epsilon: 0.99
# episode: 140/40000, score: 6.09, epsilon: 0.99
# episode: 141/40000, score: -48.4, epsilon: 0.99
# episode: 142/40000, score: -50.0, epsilon: 0.99
# episode: 143/40000, score: -1.5e+02, epsilon: 0.99
# episode: 144/40000, score: -1e+02, epsilon: 0.99
# episode: 145/40000, score: -1.18e+02, epsilon: 0.99
# episode: 146/40000, score: -97.6, epsilon: 0.99
# episode: 147/40000, score: -1.18e+02, epsilon: 0.99
# episode: 148/40000, score: -1.56e+02, epsilon: 0.99
# episode: 149/40000, score: 6.05, epsilon: 0.99
# episode: 150/40000, score: -1.39e+02, epsilon: 0.99
# episode: 151/40000, score: -1.98e+02, epsilon: 0.99
# episode: 152/40000, score: -89.0, epsilon: 0.99
# episode: 153/40000, score: -57.2, epsilon: 0.99
# episode: 154/40000, score: 0.92, epsilon: 0.99
# episode: 155/40000, score: -1.3e+02, epsilon: 0.99
# episode: 156/40000, score: -69.5, epsilon: 0.99
# episode: 157/40000, score: -1.7e+02, epsilon: 0.99
# episode: 158/40000, score: -1.5e+02, epsilon: 0.99
# episode: 159/40000, score: -1.4e+02, epsilon: 0.99
# episode: 160/40000, score: -27.5, epsilon: 0.99
# episode: 161/40000, score: -2.1e+02, epsilon: 0.99
# episode: 162/40000, score: -2.13e+02, epsilon: 0.99
# episode: 163/40000, score: 3.48, epsilon: 0.99
# episode: 164/40000, score: -69.5, epsilon: 0.99
# episode: 165/40000, score: -1.3e+02, epsilon: 0.99
# episode: 166/40000, score: -1.08e+02, epsilon: 0.99
# episode: 167/40000, score: -1.95e+02, epsilon: 0.99
# episode: 168/40000, score: -1.36e+02, epsilon: 0.99
# episode: 169/40000, score: -9.17, epsilon: 0.99
# episode: 170/40000, score: -79.6, epsilon: 0.99
# episode: 171/40000, score: -69.3, epsilon: 0.99
# episode: 172/40000, score: -38.3, epsilon: 0.99
# episode: 173/40000, score: -1.68e+02, epsilon: 0.99
# episode: 174/40000, score: -1.1e+02, epsilon: 0.99
# episode: 175/40000, score: -68.0, epsilon: 0.99
# episode: 176/40000, score: -94.5, epsilon: 0.99
# episode: 177/40000, score: -1.48e+02, epsilon: 0.99
# episode: 178/40000, score: -1.39e+02, epsilon: 0.99
# episode: 179/40000, score: -1.1e+02, epsilon: 0.99
# episode: 180/40000, score: -66.7, epsilon: 0.99
# episode: 181/40000, score: -70.0, epsilon: 0.99
# episode: 182/40000, score: -25.5, epsilon: 0.99
# episode: 183/40000, score: -6.63, epsilon: 0.99
# episode: 184/40000, score: -1.9e+02, epsilon: 0.99
# episode: 185/40000, score: -0.981, epsilon: 0.99
# episode: 186/40000, score: -1.3e+02, epsilon: 0.99
# episode: 187/40000, score: -29.5, epsilon: 0.99
# episode: 188/40000, score: -29.7, epsilon: 0.99
# episode: 189/40000, score: -1e+02, epsilon: 0.99
# episode: 190/40000, score: -70.0, epsilon: 0.99
# episode: 191/40000, score: -88.5, epsilon: 0.99
# episode: 192/40000, score: -84.6, epsilon: 0.99
# episode: 193/40000, score: -2.4e+02, epsilon: 0.99
# episode: 194/40000, score: -52.4, epsilon: 0.99
# episode: 195/40000, score: -79.7, epsilon: 0.99
# episode: 196/40000, score: -1.1e+02, epsilon: 0.99
# episode: 197/40000, score: -18.0, epsilon: 0.99
# episode: 198/40000, score: -66.3, epsilon: 0.99
# episode: 199/40000, score: -30.0, epsilon: 0.99
# episode: 200/40000, score: -1.4e+02, epsilon: 0.99
# episode: 201/40000, score: -1.2e+02, epsilon: 0.99
# episode: 202/40000, score: -9.96, epsilon: 0.98
# episode: 203/40000, score: -35.0, epsilon: 0.98
# episode: 204/40000, score: -1.8e+02, epsilon: 0.98
# episode: 205/40000, score: -89.9, epsilon: 0.98
# episode: 206/40000, score: -69.6, epsilon: 0.98
# episode: 207/40000, score: -26.7, epsilon: 0.98
# episode: 208/40000, score: -1.29e+02, epsilon: 0.98
# episode: 209/40000, score: -1.4e+02, epsilon: 0.98
# episode: 210/40000, score: -50.0, epsilon: 0.98
# episode: 211/40000, score: -48.9, epsilon: 0.98
# episode: 212/40000, score: -90.0, epsilon: 0.98
# episode: 213/40000, score: -90.0, epsilon: 0.98
# episode: 214/40000, score: -72.0, epsilon: 0.98
# episode: 215/40000, score: -38.0, epsilon: 0.98
# episode: 216/40000, score: -1.9e+02, epsilon: 0.98
# episode: 217/40000, score: -1e+02, epsilon: 0.98
# episode: 218/40000, score: -79.9, epsilon: 0.98
# episode: 219/40000, score: -1.9e+02, epsilon: 0.98
# episode: 220/40000, score: -17.6, epsilon: 0.98
# episode: 221/40000, score: -59.0, epsilon: 0.98
# episode: 222/40000, score: -78.0, epsilon: 0.98
# episode: 223/40000, score: -68.8, epsilon: 0.98
# episode: 224/40000, score: -99.9, epsilon: 0.98
# episode: 225/40000, score: -60.0, epsilon: 0.98
# episode: 226/40000, score: -99.3, epsilon: 0.98
# episode: 227/40000, score: -1.1e+02, epsilon: 0.98
# episode: 228/40000, score: -10.2, epsilon: 0.98
# episode: 229/40000, score: -59.4, epsilon: 0.98
# episode: 230/40000, score: -1.2e+02, epsilon: 0.98
# episode: 231/40000, score: -40.0, epsilon: 0.98
# episode: 232/40000, score: -1.15e+02, epsilon: 0.98
# episode: 233/40000, score: -1.3e+02, epsilon: 0.98
# episode: 234/40000, score: -50.0, epsilon: 0.98
# episode: 235/40000, score: -1.2e+02, epsilon: 0.98
# episode: 236/40000, score: -1.6e+02, epsilon: 0.98
# episode: 237/40000, score: -1.35e+02, epsilon: 0.98
# episode: 238/40000, score: -29.2, epsilon: 0.98
# episode: 239/40000, score: -42.3, epsilon: 0.98
# episode: 240/40000, score: -1.2e+02, epsilon: 0.98
# episode: 241/40000, score: -68.1, epsilon: 0.98
# episode: 242/40000, score: -16.1, epsilon: 0.98
# episode: 243/40000, score: 46.3, epsilon: 0.98
# episode: 244/40000, score: -90.0, epsilon: 0.98
# episode: 245/40000, score: -1.6e+02, epsilon: 0.98
# episode: 246/40000, score: -1e+02, epsilon: 0.98
# episode: 247/40000, score: -1.19e+02, epsilon: 0.98
# episode: 248/40000, score: -1.47e+02, epsilon: 0.98
# episode: 249/40000, score: -1.39e+02, epsilon: 0.98
# episode: 250/40000, score: -89.9, epsilon: 0.98
# episode: 251/40000, score: -67.4, epsilon: 0.98
# episode: 252/40000, score: -62.7, epsilon: 0.98
# episode: 253/40000, score: -1.07e+02, epsilon: 0.98
# episode: 254/40000, score: -1.7e+02, epsilon: 0.98
# episode: 255/40000, score: -1.1e+02, epsilon: 0.98
# episode: 256/40000, score: -1e+02, epsilon: 0.98
# episode: 257/40000, score: 75.2, epsilon: 0.98
# episode: 258/40000, score: -10.2, epsilon: 0.98
# episode: 259/40000, score: -77.6, epsilon: 0.98
# episode: 260/40000, score: 4.37, epsilon: 0.98
# episode: 261/40000, score: -1.6e+02, epsilon: 0.98
# episode: 262/40000, score: -1.1e+02, epsilon: 0.98
# episode: 263/40000, score: -1.24e+02, epsilon: 0.98
# episode: 264/40000, score: -1.56e+02, epsilon: 0.98
# episode: 265/40000, score: -69.7, epsilon: 0.98
# episode: 266/40000, score: -20.0, epsilon: 0.98
# episode: 267/40000, score: -27.6, epsilon: 0.98
# episode: 268/40000, score: -90.0, epsilon: 0.98
# episode: 269/40000, score: 30.8, epsilon: 0.98
# episode: 270/40000, score: -1.78e+02, epsilon: 0.98
# episode: 271/40000, score: -49.9, epsilon: 0.98
# episode: 272/40000, score: -59.7, epsilon: 0.98
# episode: 273/40000, score: -58.8, epsilon: 0.98
# episode: 274/40000, score: -2.1e+02, epsilon: 0.98
# episode: 275/40000, score: -1.26e+02, epsilon: 0.98
# episode: 276/40000, score: -79.8, epsilon: 0.98
# episode: 277/40000, score: -49.6, epsilon: 0.98
# episode: 278/40000, score: -1.1e+02, epsilon: 0.98
# episode: 279/40000, score: -1.2e+02, epsilon: 0.98
# episode: 280/40000, score: -80.0, epsilon: 0.98
# episode: 281/40000, score: -48.2, epsilon: 0.98
# episode: 282/40000, score: -50.0, epsilon: 0.98
# episode: 283/40000, score: -1.16e+02, epsilon: 0.98
# episode: 284/40000, score: -27.7, epsilon: 0.98
# episode: 285/40000, score: -1.56e+02, epsilon: 0.98
# episode: 286/40000, score: -1.28e+02, epsilon: 0.98
# episode: 287/40000, score: -19.7, epsilon: 0.98
# episode: 288/40000, score: -69.9, epsilon: 0.98
# episode: 289/40000, score: -40.3, epsilon: 0.98
# episode: 290/40000, score: -69.8, epsilon: 0.98
# episode: 291/40000, score: -46.1, epsilon: 0.98
# episode: 292/40000, score: -29.8, epsilon: 0.98
# episode: 293/40000, score: -80.0, epsilon: 0.98
# episode: 294/40000, score: -1.58e+02, epsilon: 0.98
# episode: 295/40000, score: -1e+02, epsilon: 0.98
# episode: 296/40000, score: -68.2, epsilon: 0.98
# episode: 297/40000, score: -1.3e+02, epsilon: 0.98
# episode: 298/40000, score: -7.52, epsilon: 0.98
# episode: 299/40000, score: -38.1, epsilon: 0.98
# episode: 300/40000, score: -14.0, epsilon: 0.98
# episode: 301/40000, score: -54.5, epsilon: 0.98
# episode: 302/40000, score: -1.4e+02, epsilon: 0.98
# episode: 303/40000, score: -32.1, epsilon: 0.98
# episode: 304/40000, score: 25.1, epsilon: 0.98
# episode: 305/40000, score: -1.1e+02, epsilon: 0.98
# episode: 306/40000, score: -39.3, epsilon: 0.98
# episode: 307/40000, score: -31.9, epsilon: 0.98
# episode: 308/40000, score: -60.0, epsilon: 0.98
# episode: 309/40000, score: -49.8, epsilon: 0.98
# episode: 310/40000, score: -44.2, epsilon: 0.98
# episode: 311/40000, score: -89.9, epsilon: 0.98
# episode: 312/40000, score: -60.0, epsilon: 0.98
# episode: 313/40000, score: -1.93e+02, epsilon: 0.98
# episode: 314/40000, score: -1.6e+02, epsilon: 0.98
# episode: 315/40000, score: -70.0, epsilon: 0.98
# episode: 316/40000, score: -79.9, epsilon: 0.98
# episode: 317/40000, score: -70.0, epsilon: 0.98
# episode: 318/40000, score: -50.0, epsilon: 0.98
# episode: 319/40000, score: -37.3, epsilon: 0.98
# episode: 320/40000, score: -1.1e+02, epsilon: 0.98
# episode: 321/40000, score: 60.8, epsilon: 0.98
# episode: 322/40000, score: -42.4, epsilon: 0.98
# episode: 323/40000, score: -95.5, epsilon: 0.98
# episode: 324/40000, score: -1.9e+02, epsilon: 0.98
# episode: 325/40000, score: 9.0, epsilon: 0.98
# episode: 326/40000, score: -1.28e+02, epsilon: 0.98
# episode: 327/40000, score: -1.1e+02, epsilon: 0.98
# episode: 328/40000, score: -58.2, epsilon: 0.98
# episode: 329/40000, score: -48.4, epsilon: 0.98
# episode: 330/40000, score: -1.19e+02, epsilon: 0.98
# episode: 331/40000, score: -1.2e+02, epsilon: 0.98
# episode: 332/40000, score: -19.6, epsilon: 0.98
# episode: 333/40000, score: -85.4, epsilon: 0.98
# episode: 334/40000, score: -69.8, epsilon: 0.98
# episode: 335/40000, score: -1.1e+02, epsilon: 0.98
# episode: 336/40000, score: -30.0, epsilon: 0.98
# episode: 337/40000, score: -99.4, epsilon: 0.98
# episode: 338/40000, score: -59.3, epsilon: 0.98
# episode: 339/40000, score: -0.0627, epsilon: 0.97
# episode: 340/40000, score: -31.3, epsilon: 0.97
# episode: 341/40000, score: -89.7, epsilon: 0.97
# episode: 342/40000, score: -79.8, epsilon: 0.97
# episode: 343/40000, score: -1.7e+02, epsilon: 0.97
# episode: 344/40000, score: -88.6, epsilon: 0.97
# episode: 345/40000, score: -1.09e+02, epsilon: 0.97
# episode: 346/40000, score: -70.0, epsilon: 0.97
# episode: 347/40000, score: -69.5, epsilon: 0.97
# episode: 348/40000, score: -70.0, epsilon: 0.97
# episode: 349/40000, score: -1.25e+02, epsilon: 0.97
# episode: 350/40000, score: -97.3, epsilon: 0.97
# episode: 351/40000, score: -1.38e+02, epsilon: 0.97
# episode: 352/40000, score: -92.2, epsilon: 0.97
# episode: 353/40000, score: -1.01e+02, epsilon: 0.97
# episode: 354/40000, score: -48.2, epsilon: 0.97
# episode: 355/40000, score: -99.9, epsilon: 0.97
# episode: 356/40000, score: -1e+02, epsilon: 0.97
# episode: 357/40000, score: -1.7e+02, epsilon: 0.97
# episode: 358/40000, score: -76.5, epsilon: 0.97
# episode: 359/40000, score: -1.7e+02, epsilon: 0.97
# episode: 360/40000, score: -70.0, epsilon: 0.97
# episode: 361/40000, score: -2.19e+02, epsilon: 0.97
# episode: 362/40000, score: -2.19e+02, epsilon: 0.97
# episode: 363/40000, score: -77.4, epsilon: 0.97
# episode: 364/40000, score: -21.1, epsilon: 0.97
# episode: 365/40000, score: -79.3, epsilon: 0.97
# episode: 366/40000, score: -1.1e+02, epsilon: 0.97
# episode: 367/40000, score: -49.3, epsilon: 0.97
# episode: 368/40000, score: -1.1e+02, epsilon: 0.97
# episode: 369/40000, score: -1.03e+02, epsilon: 0.97
# episode: 370/40000, score: -78.7, epsilon: 0.97
# episode: 371/40000, score: -94.3, epsilon: 0.97
# episode: 372/40000, score: -2e+02, epsilon: 0.97
# episode: 373/40000, score: -2.2e+02, epsilon: 0.97
# episode: 374/40000, score: -90.0, epsilon: 0.97
# episode: 375/40000, score: -1.39e+02, epsilon: 0.97
# episode: 376/40000, score: 19.3, epsilon: 0.97
# episode: 377/40000, score: -51.5, epsilon: 0.97
# episode: 378/40000, score: -88.9, epsilon: 0.97
# episode: 379/40000, score: -34.6, epsilon: 0.97
# episode: 380/40000, score: -1.38e+02, epsilon: 0.97
# episode: 381/40000, score: -49.5, epsilon: 0.97
# episode: 382/40000, score: -1.42e+02, epsilon: 0.97
# episode: 383/40000, score: -44.1, epsilon: 0.97
# episode: 384/40000, score: -58.7, epsilon: 0.97
# episode: 385/40000, score: -22.4, epsilon: 0.97
# episode: 386/40000, score: -49.4, epsilon: 0.97
# episode: 387/40000, score: -79.9, epsilon: 0.97
# episode: 388/40000, score: -65.8, epsilon: 0.97
# episode: 389/40000, score: -29.7, epsilon: 0.97
# episode: 390/40000, score: -1e+02, epsilon: 0.97
# episode: 391/40000, score: -1.4e+02, epsilon: 0.97
# episode: 392/40000, score: -70.0, epsilon: 0.97
# episode: 393/40000, score: -1.03e+02, epsilon: 0.97
# episode: 394/40000, score: -1.7e+02, epsilon: 0.97
# episode: 395/40000, score: -39.4, epsilon: 0.97
# episode: 396/40000, score: -65.2, epsilon: 0.97
# episode: 397/40000, score: -15.1, epsilon: 0.97
# episode: 398/40000, score: -90.9, epsilon: 0.97
# episode: 399/40000, score: -1.36e+02, epsilon: 0.97
# episode: 400/40000, score: 30.2, epsilon: 0.97
# episode: 401/40000, score: -71.0, epsilon: 0.97
# episode: 402/40000, score: -94.7, epsilon: 0.97
# episode: 403/40000, score: -18.6, epsilon: 0.97
# episode: 404/40000, score: -90.0, epsilon: 0.97
# episode: 405/40000, score: -42.9, epsilon: 0.97
# episode: 406/40000, score: -1.5e+02, epsilon: 0.97
# episode: 407/40000, score: 43.3, epsilon: 0.97
# episode: 408/40000, score: -31.4, epsilon: 0.97
# episode: 409/40000, score: -26.5, epsilon: 0.97
# episode: 410/40000, score: -76.6, epsilon: 0.97
# episode: 411/40000, score: -60.3, epsilon: 0.97
# episode: 412/40000, score: -1.84e+02, epsilon: 0.97
# episode: 413/40000, score: -49.4, epsilon: 0.97
# episode: 414/40000, score: -69.2, epsilon: 0.97
# episode: 415/40000, score: -62.3, epsilon: 0.97
# episode: 416/40000, score: -50.0, epsilon: 0.97
# episode: 417/40000, score: -67.6, epsilon: 0.97
# episode: 418/40000, score: -1.1e+02, epsilon: 0.97
# episode: 419/40000, score: -1.5e+02, epsilon: 0.97
# episode: 420/40000, score: -1.8e+02, epsilon: 0.97
# episode: 421/40000, score: -1.25, epsilon: 0.97
# episode: 422/40000, score: -19.1, epsilon: 0.97
# episode: 423/40000, score: -1.3e+02, epsilon: 0.97
# episode: 424/40000, score: -88.1, epsilon: 0.97
# episode: 425/40000, score: -39.8, epsilon: 0.97
# episode: 426/40000, score: -52.4, epsilon: 0.97
# episode: 427/40000, score: -1.09e+02, epsilon: 0.97
# episode: 428/40000, score: -50.0, epsilon: 0.97
# episode: 429/40000, score: -49.6, epsilon: 0.97
# episode: 430/40000, score: -1.1e+02, epsilon: 0.97
# episode: 431/40000, score: -72.3, epsilon: 0.97
# episode: 432/40000, score: -59.8, epsilon: 0.97
# episode: 433/40000, score: -78.8, epsilon: 0.97
# episode: 434/40000, score: -28.7, epsilon: 0.97
# episode: 435/40000, score: -2.1e+02, epsilon: 0.97
# episode: 436/40000, score: -29.9, epsilon: 0.97
# episode: 437/40000, score: -50.0, epsilon: 0.97
# episode: 438/40000, score: -50.0, epsilon: 0.97
# episode: 439/40000, score: -70.0, epsilon: 0.97
# episode: 440/40000, score: -99.6, epsilon: 0.97
# episode: 441/40000, score: -87.3, epsilon: 0.97
# episode: 442/40000, score: -77.5, epsilon: 0.97
# episode: 443/40000, score: -74.8, epsilon: 0.97
# episode: 444/40000, score: -98.6, epsilon: 0.97
# episode: 445/40000, score: 73.5, epsilon: 0.97
# episode: 446/40000, score: -39.3, epsilon: 0.97
# episode: 447/40000, score: -50.0, epsilon: 0.97
# episode: 448/40000, score: -66.5, epsilon: 0.97
# episode: 449/40000, score: -90.0, epsilon: 0.97
# episode: 450/40000, score: -47.4, epsilon: 0.97
# episode: 451/40000, score: 78.6, epsilon: 0.97
# episode: 452/40000, score: -1.3e+02, epsilon: 0.97
# episode: 453/40000, score: -1.48e+02, epsilon: 0.97
# episode: 454/40000, score: -79.8, epsilon: 0.97
# episode: 455/40000, score: -76.2, epsilon: 0.97
# episode: 456/40000, score: -79.7, epsilon: 0.97
# episode: 457/40000, score: -1.4e+02, epsilon: 0.97
# episode: 458/40000, score: -86.8, epsilon: 0.97
# episode: 459/40000, score: -1.9e+02, epsilon: 0.97
# episode: 460/40000, score: -1.8e+02, epsilon: 0.97
# episode: 461/40000, score: -98.1, epsilon: 0.97
# episode: 462/40000, score: -1.2e+02, epsilon: 0.97
# episode: 463/40000, score: -1.2e+02, epsilon: 0.97
# episode: 464/40000, score: -67.2, epsilon: 0.97
# episode: 465/40000, score: -79.8, epsilon: 0.97
# episode: 466/40000, score: -44.5, epsilon: 0.97
# episode: 467/40000, score: -1.25e+02, epsilon: 0.97
# episode: 468/40000, score: -49.4, epsilon: 0.97
# episode: 469/40000, score: -1.29e+02, epsilon: 0.97
# episode: 470/40000, score: -1.18e+02, epsilon: 0.97
# episode: 471/40000, score: -85.3, epsilon: 0.97
# episode: 472/40000, score: -19.5, epsilon: 0.97
# episode: 473/40000, score: -99.7, epsilon: 0.97
# episode: 474/40000, score: -80.0, epsilon: 0.97
# episode: 475/40000, score: -39.0, epsilon: 0.97
# episode: 476/40000, score: -80.0, epsilon: 0.96
# episode: 477/40000, score: -1.65e+02, epsilon: 0.96
# episode: 478/40000, score: -1e+02, epsilon: 0.96
# episode: 479/40000, score: 3.91, epsilon: 0.96
# episode: 480/40000, score: -59.8, epsilon: 0.96
# episode: 481/40000, score: -50.0, epsilon: 0.96
# episode: 482/40000, score: -1.5e+02, epsilon: 0.96
# episode: 483/40000, score: -60.0, epsilon: 0.96
# episode: 484/40000, score: -57.4, epsilon: 0.96
# episode: 485/40000, score: -1.6e+02, epsilon: 0.96
# episode: 486/40000, score: -1.1e+02, epsilon: 0.96
# episode: 487/40000, score: 36.2, epsilon: 0.96
# episode: 488/40000, score: -89.1, epsilon: 0.96
# episode: 489/40000, score: -80.0, epsilon: 0.96
# episode: 490/40000, score: -1.1e+02, epsilon: 0.96
# episode: 491/40000, score: -89.3, epsilon: 0.96
# episode: 492/40000, score: -81.2, epsilon: 0.96
# episode: 493/40000, score: -1e+02, epsilon: 0.96
# episode: 494/40000, score: -1.1e+02, epsilon: 0.96
# episode: 495/40000, score: -69.8, epsilon: 0.96
# episode: 496/40000, score: -1.07e+02, epsilon: 0.96
# episode: 497/40000, score: -80.0, epsilon: 0.96
# episode: 498/40000, score: -1.17e+02, epsilon: 0.96
# episode: 499/40000, score: -1.3e+02, epsilon: 0.96
# episode: 500/40000, score: -1.38e+02, epsilon: 0.96
# episode: 501/40000, score: -1.87e+02, epsilon: 0.96
# episode: 502/40000, score: -76.2, epsilon: 0.96
# episode: 503/40000, score: -17.9, epsilon: 0.96
# episode: 504/40000, score: -1.09e+02, epsilon: 0.96
# episode: 505/40000, score: -74.4, epsilon: 0.96
# episode: 506/40000, score: -62.7, epsilon: 0.96
# episode: 507/40000, score: -1.4e+02, epsilon: 0.96
# episode: 508/40000, score: -60.0, epsilon: 0.96
# episode: 509/40000, score: -1.7e+02, epsilon: 0.96
# episode: 510/40000, score: -1.2e+02, epsilon: 0.96
# episode: 511/40000, score: -1.19e+02, epsilon: 0.96
# episode: 512/40000, score: -60.0, epsilon: 0.96
# episode: 513/40000, score: -87.4, epsilon: 0.96
# episode: 514/40000, score: -94.3, epsilon: 0.96
# episode: 515/40000, score: -2.3e+02, epsilon: 0.96
# episode: 516/40000, score: -37.0, epsilon: 0.96
# episode: 517/40000, score: -1.69e+02, epsilon: 0.96
# episode: 518/40000, score: -56.0, epsilon: 0.96
# episode: 519/40000, score: -1.4e+02, epsilon: 0.96
# episode: 520/40000, score: -33.5, epsilon: 0.96
# episode: 521/40000, score: -58.8, epsilon: 0.96
# episode: 522/40000, score: -3.41, epsilon: 0.96
# episode: 523/40000, score: -2e+02, epsilon: 0.96
# episode: 524/40000, score: -1.5e+02, epsilon: 0.96
# episode: 525/40000, score: -1.3e+02, epsilon: 0.96
# episode: 526/40000, score: -60.4, epsilon: 0.96
# episode: 527/40000, score: -35.7, epsilon: 0.96
# episode: 528/40000, score: -70.9, epsilon: 0.96
# episode: 529/40000, score: -1.05e+02, epsilon: 0.96
# episode: 530/40000, score: -79.3, epsilon: 0.96
# episode: 531/40000, score: -60.0, epsilon: 0.96
# episode: 532/40000, score: -68.9, epsilon: 0.96
# episode: 533/40000, score: -1.79, epsilon: 0.96
# episode: 534/40000, score: -59.8, epsilon: 0.96
# episode: 535/40000, score: -79.8, epsilon: 0.96
# episode: 536/40000, score: -90.0, epsilon: 0.96
# episode: 537/40000, score: -69.0, epsilon: 0.96
# episode: 538/40000, score: -52.2, epsilon: 0.96
# episode: 539/40000, score: 64.4, epsilon: 0.96
# episode: 540/40000, score: 38.8, epsilon: 0.96
# episode: 541/40000, score: -1e+02, epsilon: 0.96
# episode: 542/40000, score: -1.7e+02, epsilon: 0.96
# episode: 543/40000, score: -41.2, epsilon: 0.96
# episode: 544/40000, score: -1.8e+02, epsilon: 0.96
# episode: 545/40000, score: -1.6e+02, epsilon: 0.96
# episode: 546/40000, score: -99.9, epsilon: 0.96
# episode: 547/40000, score: -79.8, epsilon: 0.96
# episode: 548/40000, score: -1.4e+02, epsilon: 0.96
# episode: 549/40000, score: -1.2e+02, epsilon: 0.96
# episode: 550/40000, score: -32.0, epsilon: 0.96
# episode: 551/40000, score: -49.3, epsilon: 0.96
# episode: 552/40000, score: -41.4, epsilon: 0.96
# episode: 553/40000, score: -48.8, epsilon: 0.96
# episode: 554/40000, score: -69.8, epsilon: 0.96
# episode: 555/40000, score: -38.5, epsilon: 0.96
# episode: 556/40000, score: -1.07e+02, epsilon: 0.96
# episode: 557/40000, score: -49.6, epsilon: 0.96
# episode: 558/40000, score: -59.1, epsilon: 0.96
# episode: 559/40000, score: -48.0, epsilon: 0.96
# episode: 560/40000, score: -2.49e+02, epsilon: 0.96
# episode: 561/40000, score: -44.0, epsilon: 0.96
# episode: 562/40000, score: -1e+02, epsilon: 0.96
# episode: 563/40000, score: -40.0, epsilon: 0.96
# episode: 564/40000, score: -1.21e+02, epsilon: 0.96
# episode: 565/40000, score: -92.4, epsilon: 0.96
# episode: 566/40000, score: -70.0, epsilon: 0.96
# episode: 567/40000, score: -1.7e+02, epsilon: 0.96
# episode: 568/40000, score: 47.8, epsilon: 0.96
# episode: 569/40000, score: -1e+02, epsilon: 0.96
# episode: 570/40000, score: -97.7, epsilon: 0.96
# episode: 571/40000, score: -30.3, epsilon: 0.96
# episode: 572/40000, score: -39.9, epsilon: 0.96
# episode: 573/40000, score: -49.5, epsilon: 0.96
# episode: 574/40000, score: -33.0, epsilon: 0.96
# episode: 575/40000, score: -1.39e+02, epsilon: 0.96
# episode: 576/40000, score: -78.5, epsilon: 0.96
# episode: 577/40000, score: -60.0, epsilon: 0.96
# episode: 578/40000, score: -59.5, epsilon: 0.96
# episode: 579/40000, score: -70.0, epsilon: 0.96
# episode: 580/40000, score: -67.7, epsilon: 0.96
# episode: 581/40000, score: -1.87e+02, epsilon: 0.96
# episode: 582/40000, score: -89.7, epsilon: 0.96
# episode: 583/40000, score: -49.8, epsilon: 0.96
# episode: 584/40000, score: -59.5, epsilon: 0.96
# episode: 585/40000, score: -1.9e+02, epsilon: 0.96
# episode: 586/40000, score: -58.5, epsilon: 0.96
# episode: 587/40000, score: -1.2e+02, epsilon: 0.96
# episode: 588/40000, score: -1.1e+02, epsilon: 0.96
# episode: 589/40000, score: -80.0, epsilon: 0.96
# episode: 590/40000, score: -70.0, epsilon: 0.96
# episode: 591/40000, score: -1.1e+02, epsilon: 0.96
# episode: 592/40000, score: -1.5e+02, epsilon: 0.96
# episode: 593/40000, score: -70.0, epsilon: 0.96
# episode: 594/40000, score: -38.8, epsilon: 0.96
# episode: 595/40000, score: -1.79e+02, epsilon: 0.96
# episode: 596/40000, score: -1.2e+02, epsilon: 0.96
# episode: 597/40000, score: -1.46e+02, epsilon: 0.96
# episode: 598/40000, score: -1.09e+02, epsilon: 0.96
# episode: 599/40000, score: -1.36e+02, epsilon: 0.96
# episode: 600/40000, score: -1.2e+02, epsilon: 0.96
# episode: 601/40000, score: 16.7, epsilon: 0.96
# episode: 602/40000, score: -67.0, epsilon: 0.96
# episode: 603/40000, score: -5.79, epsilon: 0.96
# episode: 604/40000, score: -1.3e+02, epsilon: 0.96
# episode: 605/40000, score: -50.0, epsilon: 0.96
# episode: 606/40000, score: -79.5, epsilon: 0.96
# episode: 607/40000, score: 26.3, epsilon: 0.96
# episode: 608/40000, score: -78.4, epsilon: 0.96
# episode: 609/40000, score: 5.79, epsilon: 0.96
# episode: 610/40000, score: -39.1, epsilon: 0.96
# episode: 611/40000, score: 0.00888, epsilon: 0.96
# episode: 612/40000, score: -77.2, epsilon: 0.96
# episode: 613/40000, score: 67.6, epsilon: 0.96
# episode: 614/40000, score: 7.75, epsilon: 0.96
# episode: 615/40000, score: -75.1, epsilon: 0.95
# episode: 616/40000, score: -55.6, epsilon: 0.95
# episode: 617/40000, score: -1.4e+02, epsilon: 0.95
# episode: 618/40000, score: -6.04, epsilon: 0.95
# episode: 619/40000, score: -1.4e+02, epsilon: 0.95
# episode: 620/40000, score: -65.1, epsilon: 0.95
# episode: 621/40000, score: -50.0, epsilon: 0.95
# episode: 622/40000, score: -1.5e+02, epsilon: 0.95
# episode: 623/40000, score: -1.6e+02, epsilon: 0.95
# episode: 624/40000, score: -1e+02, epsilon: 0.95
# episode: 625/40000, score: -2e+02, epsilon: 0.95
# episode: 626/40000, score: 36.9, epsilon: 0.95
# episode: 627/40000, score: -1.2e+02, epsilon: 0.95
# episode: 628/40000, score: -1.03e+02, epsilon: 0.95
# episode: 629/40000, score: -49.4, epsilon: 0.95
# episode: 630/40000, score: -50.0, epsilon: 0.95
# episode: 631/40000, score: -1.1e+02, epsilon: 0.95
# episode: 632/40000, score: -59.9, epsilon: 0.95
# episode: 633/40000, score: -70.0, epsilon: 0.95
# episode: 634/40000, score: -1.2e+02, epsilon: 0.95
# episode: 635/40000, score: -57.3, epsilon: 0.95
# episode: 636/40000, score: -1.1e+02, epsilon: 0.95
# episode: 637/40000, score: -1.4e+02, epsilon: 0.95
# episode: 638/40000, score: -47.1, epsilon: 0.95
# episode: 639/40000, score: -78.3, epsilon: 0.95
# episode: 640/40000, score: -90.0, epsilon: 0.95
# episode: 641/40000, score: -39.7, epsilon: 0.95
# episode: 642/40000, score: -79.5, epsilon: 0.95
# episode: 643/40000, score: -60.0, epsilon: 0.95
# episode: 644/40000, score: -1.1e+02, epsilon: 0.95
# episode: 645/40000, score: 44.7, epsilon: 0.95
# episode: 646/40000, score: -21.5, epsilon: 0.95
# episode: 647/40000, score: -1.2e+02, epsilon: 0.95
# episode: 648/40000, score: -1.8e+02, epsilon: 0.95
# episode: 649/40000, score: -9.95, epsilon: 0.95
# episode: 650/40000, score: -1.44e+02, epsilon: 0.95
# episode: 651/40000, score: -30.9, epsilon: 0.95
# episode: 652/40000, score: -88.7, epsilon: 0.95
# episode: 653/40000, score: 1.5, epsilon: 0.95
# episode: 654/40000, score: -82.5, epsilon: 0.95
# episode: 655/40000, score: -11.0, epsilon: 0.95
# episode: 656/40000, score: 20.6, epsilon: 0.95
# episode: 657/40000, score: -1.1e+02, epsilon: 0.95
# episode: 658/40000, score: -46.1, epsilon: 0.95
# episode: 659/40000, score: -46.6, epsilon: 0.95
# episode: 660/40000, score: -88.8, epsilon: 0.95
# episode: 661/40000, score: -84.3, epsilon: 0.95
# episode: 662/40000, score: -1.2e+02, epsilon: 0.95
# episode: 663/40000, score: -88.2, epsilon: 0.95
# episode: 664/40000, score: -1.4e+02, epsilon: 0.95
# episode: 665/40000, score: -1.16e+02, epsilon: 0.95
# episode: 666/40000, score: -70.0, epsilon: 0.95
# episode: 667/40000, score: 57.9, epsilon: 0.95
# episode: 668/40000, score: -59.6, epsilon: 0.95
# episode: 669/40000, score: -1.2e+02, epsilon: 0.95
# episode: 670/40000, score: 62.4, epsilon: 0.95
# episode: 671/40000, score: -1.5e+02, epsilon: 0.95
# episode: 672/40000, score: -68.7, epsilon: 0.95
# episode: 673/40000, score: -49.8, epsilon: 0.95
# episode: 674/40000, score: -49.8, epsilon: 0.95
# episode: 675/40000, score: -26.8, epsilon: 0.95
# episode: 676/40000, score: -97.0, epsilon: 0.95
# episode: 677/40000, score: -1.77e+02, epsilon: 0.95
# episode: 678/40000, score: -79.0, epsilon: 0.95
# episode: 679/40000, score: -70.0, epsilon: 0.95
# episode: 680/40000, score: -1.12e+02, epsilon: 0.95
# episode: 681/40000, score: -30.4, epsilon: 0.95
# episode: 682/40000, score: 55.0, epsilon: 0.95
# episode: 683/40000, score: -80.0, epsilon: 0.95
# episode: 684/40000, score: -1.38e+02, epsilon: 0.95
# episode: 685/40000, score: -69.3, epsilon: 0.95
# episode: 686/40000, score: -1.25e+02, epsilon: 0.95
# episode: 687/40000, score: -1.43e+02, epsilon: 0.95
# episode: 688/40000, score: -67.5, epsilon: 0.95
# episode: 689/40000, score: -68.2, epsilon: 0.95
# episode: 690/40000, score: -87.8, epsilon: 0.95
# episode: 691/40000, score: -1.17e+02, epsilon: 0.95
# episode: 692/40000, score: -1e+02, epsilon: 0.95
# episode: 693/40000, score: -67.9, epsilon: 0.95
# episode: 694/40000, score: -56.4, epsilon: 0.95
# episode: 695/40000, score: -99.8, epsilon: 0.95
# episode: 696/40000, score: -72.6, epsilon: 0.95
# episode: 697/40000, score: -79.9, epsilon: 0.95
# episode: 698/40000, score: -58.6, epsilon: 0.95
# episode: 699/40000, score: -57.6, epsilon: 0.95
# episode: 700/40000, score: -1.06e+02, epsilon: 0.95
# episode: 701/40000, score: -50.0, epsilon: 0.95
# episode: 702/40000, score: -1.7e+02, epsilon: 0.95
# episode: 703/40000, score: 5.1, epsilon: 0.95
# episode: 704/40000, score: -88.8, epsilon: 0.95
# episode: 705/40000, score: -21.2, epsilon: 0.95
# episode: 706/40000, score: -1.53e+02, epsilon: 0.95
# episode: 707/40000, score: -79.1, epsilon: 0.95
# episode: 708/40000, score: -69.8, epsilon: 0.95
# episode: 709/40000, score: -1e+02, epsilon: 0.95
# episode: 710/40000, score: -1.65e+02, epsilon: 0.95
# episode: 711/40000, score: -1.28e+02, epsilon: 0.95
# episode: 712/40000, score: -1.06e+02, epsilon: 0.95
# episode: 713/40000, score: 75.8, epsilon: 0.95
# episode: 714/40000, score: -49.1, epsilon: 0.95
# episode: 715/40000, score: -5.12, epsilon: 0.95
# episode: 716/40000, score: -89.9, epsilon: 0.95
# episode: 717/40000, score: -1.7e+02, epsilon: 0.95
# episode: 718/40000, score: 1.55, epsilon: 0.95
# episode: 719/40000, score: -29.8, epsilon: 0.95
# episode: 720/40000, score: -1.1e+02, epsilon: 0.95
# episode: 721/40000, score: -52.3, epsilon: 0.95
# episode: 722/40000, score: -61.7, epsilon: 0.95
# episode: 723/40000, score: -66.0, epsilon: 0.95
# episode: 724/40000, score: -69.7, epsilon: 0.95
# episode: 725/40000, score: -60.0, epsilon: 0.95
# episode: 726/40000, score: -1.59e+02, epsilon: 0.95
# episode: 727/40000, score: 8.54, epsilon: 0.95
# episode: 728/40000, score: -1.4e+02, epsilon: 0.95
# episode: 729/40000, score: -1.1e+02, epsilon: 0.95
# episode: 730/40000, score: -1.11e+02, epsilon: 0.95
# episode: 731/40000, score: -2e+02, epsilon: 0.95
# episode: 732/40000, score: -20.0, epsilon: 0.95
# episode: 733/40000, score: 40.8, epsilon: 0.95
# episode: 734/40000, score: -62.9, epsilon: 0.95
# episode: 735/40000, score: -89.8, epsilon: 0.95
# episode: 736/40000, score: -1.58e+02, epsilon: 0.95
# episode: 737/40000, score: -1.18e+02, epsilon: 0.95
# episode: 738/40000, score: -89.1, epsilon: 0.95
# episode: 739/40000, score: -47.4, epsilon: 0.95
# episode: 740/40000, score: -77.4, epsilon: 0.95
# episode: 741/40000, score: -1.1e+02, epsilon: 0.95
# episode: 742/40000, score: -43.4, epsilon: 0.95
# episode: 743/40000, score: -6.67, epsilon: 0.95
# episode: 744/40000, score: -79.7, epsilon: 0.95
# episode: 745/40000, score: -78.3, epsilon: 0.95
# episode: 746/40000, score: 14.4, epsilon: 0.95
# episode: 747/40000, score: -88.5, epsilon: 0.95
# episode: 748/40000, score: -1.08e+02, epsilon: 0.95
# episode: 749/40000, score: -28.7, epsilon: 0.95
# episode: 750/40000, score: -2e+02, epsilon: 0.95
# episode: 751/40000, score: -30.0, epsilon: 0.95
# episode: 752/40000, score: -1.69e+02, epsilon: 0.95
# episode: 753/40000, score: -3.5, epsilon: 0.95
# episode: 754/40000, score: -89.9, epsilon: 0.95
# episode: 755/40000, score: -11.8, epsilon: 0.95
# episode: 756/40000, score: -2.5e+02, epsilon: 0.94
# episode: 757/40000, score: -59.8, epsilon: 0.94
# episode: 758/40000, score: -1.09e+02, epsilon: 0.94
# episode: 759/40000, score: -80.0, epsilon: 0.94
# episode: 760/40000, score: -99.6, epsilon: 0.94
# episode: 761/40000, score: -1.8e+02, epsilon: 0.94
# episode: 762/40000, score: -59.3, epsilon: 0.94
# episode: 763/40000, score: -1.08e+02, epsilon: 0.94
# episode: 764/40000, score: -2.1e+02, epsilon: 0.94
# episode: 765/40000, score: -83.5, epsilon: 0.94
# episode: 766/40000, score: -19.6, epsilon: 0.94
# episode: 767/40000, score: -54.5, epsilon: 0.94
# episode: 768/40000, score: -59.9, epsilon: 0.94
# episode: 769/40000, score: -57.8, epsilon: 0.94
# episode: 770/40000, score: -1.16e+02, epsilon: 0.94
# episode: 771/40000, score: -19.9, epsilon: 0.94
# episode: 772/40000, score: -44.7, epsilon: 0.94
# episode: 773/40000, score: -12.3, epsilon: 0.94
# episode: 774/40000, score: -29.9, epsilon: 0.94
# episode: 775/40000, score: -98.0, epsilon: 0.94
# episode: 776/40000, score: -49.7, epsilon: 0.94
# episode: 777/40000, score: -1e+02, epsilon: 0.94
# episode: 778/40000, score: -26.1, epsilon: 0.94
# episode: 779/40000, score: -49.4, epsilon: 0.94
# episode: 780/40000, score: -1.1e+02, epsilon: 0.94
# episode: 781/40000, score: -89.4, epsilon: 0.94
# episode: 782/40000, score: -87.8, epsilon: 0.94
# episode: 783/40000, score: -57.4, epsilon: 0.94
# episode: 784/40000, score: -89.1, epsilon: 0.94
# episode: 785/40000, score: -26.6, epsilon: 0.94
# episode: 786/40000, score: -30.0, epsilon: 0.94
# episode: 787/40000, score: -81.1, epsilon: 0.94
# episode: 788/40000, score: -1.1e+02, epsilon: 0.94
# episode: 789/40000, score: -1.59e+02, epsilon: 0.94
# episode: 790/40000, score: -1.38e+02, epsilon: 0.94
# episode: 791/40000, score: -59.9, epsilon: 0.94
# episode: 792/40000, score: 19.6, epsilon: 0.94
# episode: 793/40000, score: -59.9, epsilon: 0.94
# episode: 794/40000, score: -1.2e+02, epsilon: 0.94
# episode: 795/40000, score: -83.0, epsilon: 0.94
# episode: 796/40000, score: -58.9, epsilon: 0.94
# episode: 797/40000, score: -1.08e+02, epsilon: 0.94
# episode: 798/40000, score: -50.0, epsilon: 0.94
# episode: 799/40000, score: -54.4, epsilon: 0.94
# episode: 800/40000, score: 62.9, epsilon: 0.94
# episode: 801/40000, score: -1.48e+02, epsilon: 0.94
# episode: 802/40000, score: -77.3, epsilon: 0.94
# episode: 803/40000, score: -89.4, epsilon: 0.94
# episode: 804/40000, score: -1.23e+02, epsilon: 0.94
# episode: 805/40000, score: -36.5, epsilon: 0.94
# episode: 806/40000, score: -44.5, epsilon: 0.94
# episode: 807/40000, score: -69.6, epsilon: 0.94
# episode: 808/40000, score: -80.0, epsilon: 0.94
# episode: 809/40000, score: -1.7e+02, epsilon: 0.94
# episode: 810/40000, score: -70.0, epsilon: 0.94
# episode: 811/40000, score: -1.89e+02, epsilon: 0.94
# episode: 812/40000, score: -82.8, epsilon: 0.94
# episode: 813/40000, score: -49.5, epsilon: 0.94
# episode: 814/40000, score: -1.36e+02, epsilon: 0.94
# episode: 815/40000, score: -79.9, epsilon: 0.94
# episode: 816/40000, score: -49.5, epsilon: 0.94
# episode: 817/40000, score: -98.8, epsilon: 0.94
# episode: 818/40000, score: -18.8, epsilon: 0.94
# episode: 819/40000, score: -99.6, epsilon: 0.94
# episode: 820/40000, score: -80.0, epsilon: 0.94
# episode: 821/40000, score: -79.7, epsilon: 0.94
# episode: 822/40000, score: -1.5e+02, epsilon: 0.94
# episode: 823/40000, score: -99.8, epsilon: 0.94
# episode: 824/40000, score: -1.57e+02, epsilon: 0.94
# episode: 825/40000, score: -1.18e+02, epsilon: 0.94
# episode: 826/40000, score: -65.8, epsilon: 0.94
# episode: 827/40000, score: -79.9, epsilon: 0.94
# episode: 828/40000, score: -68.6, epsilon: 0.94
# episode: 829/40000, score: -1.8e+02, epsilon: 0.94
# episode: 830/40000, score: -1.48e+02, epsilon: 0.94
# episode: 831/40000, score: -35.8, epsilon: 0.94
# episode: 832/40000, score: -79.9, epsilon: 0.94
# episode: 833/40000, score: -1.22e+02, epsilon: 0.94
# episode: 834/40000, score: -60.0, epsilon: 0.94
# episode: 835/40000, score: -1.12, epsilon: 0.94
# episode: 836/40000, score: -38.7, epsilon: 0.94
# episode: 837/40000, score: -37.0, epsilon: 0.94
# episode: 838/40000, score: -1.1e+02, epsilon: 0.94
# episode: 839/40000, score: -66.3, epsilon: 0.94
# episode: 840/40000, score: -1.5e+02, epsilon: 0.94
# episode: 841/40000, score: -69.8, epsilon: 0.94
# episode: 842/40000, score: -78.2, epsilon: 0.94
# episode: 843/40000, score: -13.4, epsilon: 0.94
# episode: 844/40000, score: 26.8, epsilon: 0.94
# episode: 845/40000, score: -39.2, epsilon: 0.94
# episode: 846/40000, score: -38.4, epsilon: 0.94
# episode: 847/40000, score: -47.2, epsilon: 0.94
# episode: 848/40000, score: -1.1e+02, epsilon: 0.94
# episode: 849/40000, score: -9.92, epsilon: 0.94
# episode: 850/40000, score: -1.29e+02, epsilon: 0.94
# episode: 851/40000, score: -1.19e+02, epsilon: 0.94
# episode: 852/40000, score: -1.3e+02, epsilon: 0.94
# episode: 853/40000, score: -1.1e+02, epsilon: 0.94
# episode: 854/40000, score: -1.39e+02, epsilon: 0.94
# episode: 855/40000, score: -45.9, epsilon: 0.94
# episode: 856/40000, score: -78.2, epsilon: 0.94
# episode: 857/40000, score: -1.1e+02, epsilon: 0.94
# episode: 858/40000, score: -91.4, epsilon: 0.94
# episode: 859/40000, score: -39.9, epsilon: 0.94
# episode: 860/40000, score: -7.44, epsilon: 0.94
# episode: 861/40000, score: -45.1, epsilon: 0.94
# episode: 862/40000, score: -1.2e+02, epsilon: 0.94
# episode: 863/40000, score: -50.0, epsilon: 0.94
# episode: 864/40000, score: -90.5, epsilon: 0.94
# episode: 865/40000, score: -1.39e+02, epsilon: 0.94
# episode: 866/40000, score: -1.18e+02, epsilon: 0.94
# episode: 867/40000, score: -2.2e+02, epsilon: 0.94
# episode: 868/40000, score: -1.12e+02, epsilon: 0.94
# episode: 869/40000, score: -27.3, epsilon: 0.94
# episode: 870/40000, score: -69.6, epsilon: 0.94
# episode: 871/40000, score: -30.0, epsilon: 0.94
# episode: 872/40000, score: -1e+02, epsilon: 0.94
# episode: 873/40000, score: -89.8, epsilon: 0.94
# episode: 874/40000, score: -56.8, epsilon: 0.94
# episode: 875/40000, score: -49.9, epsilon: 0.94
# episode: 876/40000, score: -1.14e+02, epsilon: 0.94
# episode: 877/40000, score: -80.0, epsilon: 0.94
# episode: 878/40000, score: -60.0, epsilon: 0.94
# episode: 879/40000, score: -72.7, epsilon: 0.94
# episode: 880/40000, score: -25.5, epsilon: 0.94
# episode: 881/40000, score: -49.8, epsilon: 0.94
# episode: 882/40000, score: 23.8, epsilon: 0.94
# episode: 883/40000, score: -47.0, epsilon: 0.94
# episode: 884/40000, score: -1.2e+02, epsilon: 0.94
# episode: 885/40000, score: -74.3, epsilon: 0.94
# episode: 886/40000, score: -1.52e+02, epsilon: 0.94
# episode: 887/40000, score: -1.1e+02, epsilon: 0.94
# episode: 888/40000, score: -29.2, epsilon: 0.94
# episode: 889/40000, score: -1.08e+02, epsilon: 0.94
# episode: 890/40000, score: -95.8, epsilon: 0.94
# episode: 891/40000, score: -1e+02, epsilon: 0.94
# episode: 892/40000, score: -79.7, epsilon: 0.94
# episode: 893/40000, score: -1.4e+02, epsilon: 0.94
# episode: 894/40000, score: -6.02, epsilon: 0.94
# episode: 895/40000, score: -1.17e+02, epsilon: 0.94
# episode: 896/40000, score: -1e+02, epsilon: 0.94
# episode: 897/40000, score: -84.2, epsilon: 0.94
# episode: 898/40000, score: -79.4, epsilon: 0.93
# episode: 899/40000, score: -1e+02, epsilon: 0.93
# episode: 900/40000, score: 49.7, epsilon: 0.93
# episode: 901/40000, score: -1.5e+02, epsilon: 0.93
# episode: 902/40000, score: -77.2, epsilon: 0.93
# episode: 903/40000, score: -68.5, epsilon: 0.93
# episode: 904/40000, score: -1.77e+02, epsilon: 0.93
# episode: 905/40000, score: -36.0, epsilon: 0.93
# episode: 906/40000, score: -1.38e+02, epsilon: 0.93
# episode: 907/40000, score: -48.3, epsilon: 0.93
# episode: 908/40000, score: -1.5e+02, epsilon: 0.93
# episode: 909/40000, score: -1.09e+02, epsilon: 0.93
# episode: 910/40000, score: -49.9, epsilon: 0.93
# episode: 911/40000, score: -69.3, epsilon: 0.93
# episode: 912/40000, score: -70.0, epsilon: 0.93
# episode: 913/40000, score: -94.2, epsilon: 0.93
# episode: 914/40000, score: -1.4e+02, epsilon: 0.93
# episode: 915/40000, score: -9.53, epsilon: 0.93
# episode: 916/40000, score: -20.0, epsilon: 0.93
# episode: 917/40000, score: -48.3, epsilon: 0.93
# episode: 918/40000, score: -79.6, epsilon: 0.93
# episode: 919/40000, score: -58.7, epsilon: 0.93
# episode: 920/40000, score: -17.2, epsilon: 0.93
# episode: 921/40000, score: -30.0, epsilon: 0.93
# episode: 922/40000, score: -1.4e+02, epsilon: 0.93
# episode: 923/40000, score: -1.65e+02, epsilon: 0.93
# episode: 924/40000, score: -1.2e+02, epsilon: 0.93
# episode: 925/40000, score: -97.8, epsilon: 0.93
# episode: 926/40000, score: -50.0, epsilon: 0.93
# episode: 927/40000, score: -90.0, epsilon: 0.93
# episode: 928/40000, score: -1.4e+02, epsilon: 0.93
# episode: 929/40000, score: -89.8, epsilon: 0.93
# episode: 930/40000, score: -75.5, epsilon: 0.93
# episode: 931/40000, score: -49.9, epsilon: 0.93
# episode: 932/40000, score: -24.9, epsilon: 0.93
# episode: 933/40000, score: -50.0, epsilon: 0.93
# episode: 934/40000, score: -1.2e+02, epsilon: 0.93
# episode: 935/40000, score: -49.3, epsilon: 0.93
# episode: 936/40000, score: -59.7, epsilon: 0.93
# episode: 937/40000, score: -40.0, epsilon: 0.93
# episode: 938/40000, score: -10.3, epsilon: 0.93
# episode: 939/40000, score: -55.4, epsilon: 0.93
# episode: 940/40000, score: -69.9, epsilon: 0.93
# episode: 941/40000, score: -57.8, epsilon: 0.93
# episode: 942/40000, score: -1.25e+02, epsilon: 0.93
# episode: 943/40000, score: -67.8, epsilon: 0.93
# episode: 944/40000, score: -1.1e+02, epsilon: 0.93
# episode: 945/40000, score: -1e+02, epsilon: 0.93
# episode: 946/40000, score: -59.9, epsilon: 0.93
# episode: 947/40000, score: -1.38e+02, epsilon: 0.93
# episode: 948/40000, score: -48.7, epsilon: 0.93
# episode: 949/40000, score: -1.2e+02, epsilon: 0.93
# episode: 950/40000, score: -1.7e+02, epsilon: 0.93
# episode: 951/40000, score: -2e+02, epsilon: 0.93
# episode: 952/40000, score: -29.7, epsilon: 0.93
# episode: 953/40000, score: -39.9, epsilon: 0.93
# episode: 954/40000, score: -40.0, epsilon: 0.93
# episode: 955/40000, score: 20.1, epsilon: 0.93
# episode: 956/40000, score: -67.5, epsilon: 0.93
# episode: 957/40000, score: -1.2e+02, epsilon: 0.93
# episode: 958/40000, score: -1.7e+02, epsilon: 0.93
# episode: 959/40000, score: -90.0, epsilon: 0.93
# episode: 960/40000, score: -1.21e+02, epsilon: 0.93
# episode: 961/40000, score: -59.7, epsilon: 0.93
# episode: 962/40000, score: -70.0, epsilon: 0.93
# episode: 963/40000, score: -89.5, epsilon: 0.93
# episode: 964/40000, score: -46.0, epsilon: 0.93
# episode: 965/40000, score: -79.5, epsilon: 0.93
# episode: 966/40000, score: -70.0, epsilon: 0.93
# episode: 967/40000, score: -79.8, epsilon: 0.93
# episode: 968/40000, score: -1.1e+02, epsilon: 0.93
# episode: 969/40000, score: 16.4, epsilon: 0.93
# episode: 970/40000, score: -80.0, epsilon: 0.93
# episode: 971/40000, score: -66.7, epsilon: 0.93
# episode: 972/40000, score: -59.9, epsilon: 0.93
# episode: 973/40000, score: -14.8, epsilon: 0.93
# episode: 974/40000, score: 20.4, epsilon: 0.93
# episode: 975/40000, score: -62.2, epsilon: 0.93
# episode: 976/40000, score: -1.1e+02, epsilon: 0.93
# episode: 977/40000, score: -1.2e+02, epsilon: 0.93
# episode: 978/40000, score: -1.5e+02, epsilon: 0.93
# episode: 979/40000, score: -48.9, epsilon: 0.93
# ...
# episode: 39678/40000, score: 88.9, epsilon: 0.051
# episode: 39679/40000, score: 92.9, epsilon: 0.051
# episode: 39680/40000, score: 25.1, epsilon: 0.051
# episode: 39681/40000, score: 90.8, epsilon: 0.051
# episode: 39682/40000, score: 78.1, epsilon: 0.051
# episode: 39683/40000, score: 92.7, epsilon: 0.051
# episode: 39684/40000, score: 92.7, epsilon: 0.051
# episode: 39685/40000, score: 84.3, epsilon: 0.051
# episode: 39686/40000, score: 95.5, epsilon: 0.051
# episode: 39687/40000, score: 93.5, epsilon: 0.051
# episode: 39688/40000, score: 96.2, epsilon: 0.051
# episode: 39689/40000, score: 87.2, epsilon: 0.051
# episode: 39690/40000, score: 95.0, epsilon: 0.051
# episode: 39691/40000, score: 54.3, epsilon: 0.051
# episode: 39692/40000, score: 94.6, epsilon: 0.051
# episode: 39693/40000, score: 93.6, epsilon: 0.051
# episode: 39694/40000, score: 96.0, epsilon: 0.051
# episode: 39695/40000, score: 94.5, epsilon: 0.051
# episode: 39696/40000, score: 94.2, epsilon: 0.051
# episode: 39697/40000, score: 68.0, epsilon: 0.051
# episode: 39698/40000, score: 94.6, epsilon: 0.051
# episode: 39699/40000, score: 93.4, epsilon: 0.051
# episode: 39700/40000, score: 78.6, epsilon: 0.051
# episode: 39701/40000, score: 4.1, epsilon: 0.051
# episode: 39702/40000, score: -7.96, epsilon: 0.051
# episode: 39703/40000, score: 70.3, epsilon: 0.051
# episode: 39704/40000, score: 92.3, epsilon: 0.051
# episode: 39705/40000, score: 95.9, epsilon: 0.051
# episode: 39706/40000, score: 94.3, epsilon: 0.051
# episode: 39707/40000, score: 93.8, epsilon: 0.051
# episode: 39708/40000, score: 95.7, epsilon: 0.051
# episode: 39709/40000, score: 83.2, epsilon: 0.051
# episode: 39710/40000, score: 95.7, epsilon: 0.051
# episode: 39711/40000, score: 86.9, epsilon: 0.051
# episode: 39712/40000, score: 88.9, epsilon: 0.051
# episode: 39713/40000, score: 91.7, epsilon: 0.051
# episode: 39714/40000, score: 93.1, epsilon: 0.051
# episode: 39715/40000, score: 95.1, epsilon: 0.051
# episode: 39716/40000, score: 92.5, epsilon: 0.051
# episode: 39717/40000, score: 90.4, epsilon: 0.051
# episode: 39718/40000, score: 80.9, epsilon: 0.051
# episode: 39719/40000, score: 91.7, epsilon: 0.051
# episode: 39720/40000, score: 93.7, epsilon: 0.051
# episode: 39721/40000, score: 91.7, epsilon: 0.051
# episode: 39722/40000, score: 92.1, epsilon: 0.051
# episode: 39723/40000, score: 93.1, epsilon: 0.051
# episode: 39724/40000, score: 94.1, epsilon: 0.051
# episode: 39725/40000, score: 93.0, epsilon: 0.051
# episode: 39726/40000, score: 97.0, epsilon: 0.051
# episode: 39727/40000, score: 91.4, epsilon: 0.051
# episode: 39728/40000, score: 81.1, epsilon: 0.051
# episode: 39729/40000, score: 72.7, epsilon: 0.051
# episode: 39730/40000, score: 93.8, epsilon: 0.051
# episode: 39731/40000, score: 75.8, epsilon: 0.051
# episode: 39732/40000, score: 89.3, epsilon: 0.051
# episode: 39733/40000, score: 94.2, epsilon: 0.051
# episode: 39734/40000, score: 90.3, epsilon: 0.051
# episode: 39735/40000, score: 92.6, epsilon: 0.051
# episode: 39736/40000, score: 92.1, epsilon: 0.051
# episode: 39737/40000, score: 93.8, epsilon: 0.051
# episode: 39738/40000, score: 82.7, epsilon: 0.051
# episode: 39739/40000, score: 96.2, epsilon: 0.051
# episode: 39740/40000, score: 98.4, epsilon: 0.051
# episode: 39741/40000, score: 94.0, epsilon: 0.051
# episode: 39742/40000, score: 89.7, epsilon: 0.051
# episode: 39743/40000, score: 87.8, epsilon: 0.051
# episode: 39744/40000, score: 83.9, epsilon: 0.051
# episode: 39745/40000, score: 69.5, epsilon: 0.051
# episode: 39746/40000, score: 92.1, epsilon: 0.051
# episode: 39747/40000, score: 87.4, epsilon: 0.051
# episode: 39748/40000, score: 88.9, epsilon: 0.051
# episode: 39749/40000, score: 77.8, epsilon: 0.051
# episode: 39750/40000, score: 93.9, epsilon: 0.051
# episode: 39751/40000, score: 94.8, epsilon: 0.051
# episode: 39752/40000, score: 42.7, epsilon: 0.051
# episode: 39753/40000, score: 78.9, epsilon: 0.051
# episode: 39754/40000, score: 91.7, epsilon: 0.051
# episode: 39755/40000, score: 95.1, epsilon: 0.051
# episode: 39756/40000, score: 95.1, epsilon: 0.051
# episode: 39757/40000, score: 94.7, epsilon: 0.051
# episode: 39758/40000, score: 91.7, epsilon: 0.051
# episode: 39759/40000, score: 82.1, epsilon: 0.051
# episode: 39760/40000, score: 94.1, epsilon: 0.051
# episode: 39761/40000, score: 94.7, epsilon: 0.051
# episode: 39762/40000, score: 60.0, epsilon: 0.051
# episode: 39763/40000, score: 96.0, epsilon: 0.051
# episode: 39764/40000, score: -10.0, epsilon: 0.051
# episode: 39765/40000, score: 78.7, epsilon: 0.051
# episode: 39766/40000, score: 92.8, epsilon: 0.051
# episode: 39767/40000, score: 57.4, epsilon: 0.051
# episode: 39768/40000, score: -9.24, epsilon: 0.051
# episode: 39769/40000, score: 93.2, epsilon: 0.051
# episode: 39770/40000, score: 90.3, epsilon: 0.051
# episode: 39771/40000, score: 84.3, epsilon: 0.051
# episode: 39772/40000, score: 96.9, epsilon: 0.051
# episode: 39773/40000, score: 90.1, epsilon: 0.051
# episode: 39774/40000, score: 90.7, epsilon: 0.051
# episode: 39775/40000, score: 89.2, epsilon: 0.051
# episode: 39776/40000, score: 29.6, epsilon: 0.051
# episode: 39777/40000, score: 82.0, epsilon: 0.051
# episode: 39778/40000, score: 76.8, epsilon: 0.051
# episode: 39779/40000, score: 94.9, epsilon: 0.051
# episode: 39780/40000, score: 94.6, epsilon: 0.051
# episode: 39781/40000, score: 68.1, epsilon: 0.051
# episode: 39782/40000, score: 94.5, epsilon: 0.051
# episode: 39783/40000, score: 96.4, epsilon: 0.051
# episode: 39784/40000, score: 95.0, epsilon: 0.051
# episode: 39785/40000, score: 69.0, epsilon: 0.051
# episode: 39786/40000, score: 87.0, epsilon: 0.051
# episode: 39787/40000, score: 37.9, epsilon: 0.051
# episode: 39788/40000, score: 82.0, epsilon: 0.051
# episode: 39789/40000, score: 94.8, epsilon: 0.051
# episode: 39790/40000, score: 90.3, epsilon: 0.051
# episode: 39791/40000, score: 79.2, epsilon: 0.051
# episode: 39792/40000, score: 94.2, epsilon: 0.051
# episode: 39793/40000, score: 89.0, epsilon: 0.051
# episode: 39794/40000, score: 86.8, epsilon: 0.051
# episode: 39795/40000, score: 82.8, epsilon: 0.051
# episode: 39796/40000, score: 84.6, epsilon: 0.051
# episode: 39797/40000, score: 90.3, epsilon: 0.051
# episode: 39798/40000, score: 79.7, epsilon: 0.051
# episode: 39799/40000, score: 91.4, epsilon: 0.051
# episode: 39800/40000, score: 93.3, epsilon: 0.051
# episode: 39801/40000, score: 89.0, epsilon: 0.051
# episode: 39802/40000, score: 96.5, epsilon: 0.051
# episode: 39803/40000, score: 82.0, epsilon: 0.051
# episode: 39804/40000, score: 92.1, epsilon: 0.051
# episode: 39805/40000, score: 64.5, epsilon: 0.051
# episode: 39806/40000, score: 84.1, epsilon: 0.051
# episode: 39807/40000, score: 89.5, epsilon: 0.051
# episode: 39808/40000, score: 95.9, epsilon: 0.051
# episode: 39809/40000, score: 89.2, epsilon: 0.051
# episode: 39810/40000, score: 69.5, epsilon: 0.051
# episode: 39811/40000, score: 90.1, epsilon: 0.051
# episode: 39812/40000, score: 81.9, epsilon: 0.051
# episode: 39813/40000, score: 82.4, epsilon: 0.051
# episode: 39814/40000, score: 95.6, epsilon: 0.051
# episode: 39815/40000, score: 94.9, epsilon: 0.051
# episode: 39816/40000, score: 80.4, epsilon: 0.051
# episode: 39817/40000, score: 95.1, epsilon: 0.051
# episode: 39818/40000, score: 96.3, epsilon: 0.051
# episode: 39819/40000, score: 24.8, epsilon: 0.051
# episode: 39820/40000, score: 93.7, epsilon: 0.051
# episode: 39821/40000, score: 95.4, epsilon: 0.051
# episode: 39822/40000, score: 93.0, epsilon: 0.051
# episode: 39823/40000, score: 93.6, epsilon: 0.051
# episode: 39824/40000, score: 95.3, epsilon: 0.051
# episode: 39825/40000, score: 84.1, epsilon: 0.051
# episode: 39826/40000, score: 89.2, epsilon: 0.051
# episode: 39827/40000, score: 94.2, epsilon: 0.051
# episode: 39828/40000, score: 90.5, epsilon: 0.051
# episode: 39829/40000, score: 94.1, epsilon: 0.051
# episode: 39830/40000, score: 93.3, epsilon: 0.051
# episode: 39831/40000, score: 95.8, epsilon: 0.051
# episode: 39832/40000, score: 88.2, epsilon: 0.051
# episode: 39833/40000, score: 9.86, epsilon: 0.051
# episode: 39834/40000, score: 95.3, epsilon: 0.051
# episode: 39835/40000, score: -10.0, epsilon: 0.051
# episode: 39836/40000, score: 89.2, epsilon: 0.051
# episode: 39837/40000, score: 85.7, epsilon: 0.051
# episode: 39838/40000, score: 95.1, epsilon: 0.051
# episode: 39839/40000, score: 93.1, epsilon: 0.051
# episode: 39840/40000, score: 93.3, epsilon: 0.051
# episode: 39841/40000, score: 92.3, epsilon: 0.051
# episode: 39842/40000, score: 95.3, epsilon: 0.051
# episode: 39843/40000, score: 90.5, epsilon: 0.051
# episode: 39844/40000, score: 87.4, epsilon: 0.051
# episode: 39845/40000, score: 93.4, epsilon: 0.051
# episode: 39846/40000, score: 84.3, epsilon: 0.051
# episode: 39847/40000, score: 91.0, epsilon: 0.051
# episode: 39848/40000, score: -8.25, epsilon: 0.051
# episode: 39849/40000, score: 94.5, epsilon: 0.051
# episode: 39850/40000, score: 95.2, epsilon: 0.051
# episode: 39851/40000, score: 60.2, epsilon: 0.051
# episode: 39852/40000, score: 90.3, epsilon: 0.051
# episode: 39853/40000, score: 77.3, epsilon: 0.051
# episode: 39854/40000, score: 38.1, epsilon: 0.051
# episode: 39855/40000, score: 88.1, epsilon: 0.051
# episode: 39856/40000, score: 63.7, epsilon: 0.051
# episode: 39857/40000, score: 94.1, epsilon: 0.051
# episode: 39858/40000, score: 95.8, epsilon: 0.051
# episode: 39859/40000, score: 93.3, epsilon: 0.051
# episode: 39860/40000, score: 96.4, epsilon: 0.051
# episode: 39861/40000, score: 92.2, epsilon: 0.051
# episode: 39862/40000, score: 90.8, epsilon: 0.051
# episode: 39863/40000, score: 91.7, epsilon: 0.051
# episode: 39864/40000, score: 92.4, epsilon: 0.051
# episode: 39865/40000, score: 65.5, epsilon: 0.051
# episode: 39866/40000, score: 92.0, epsilon: 0.051
# episode: 39867/40000, score: 55.8, epsilon: 0.051
# episode: 39868/40000, score: 90.2, epsilon: 0.05
# episode: 39869/40000, score: 96.7, epsilon: 0.05
# episode: 39870/40000, score: 93.8, epsilon: 0.05
# episode: 39871/40000, score: 96.0, epsilon: 0.05
# episode: 39872/40000, score: 82.4, epsilon: 0.05
# episode: 39873/40000, score: 94.4, epsilon: 0.05
# episode: 39874/40000, score: 86.2, epsilon: 0.05
# episode: 39875/40000, score: 95.9, epsilon: 0.05
# episode: 39876/40000, score: 96.1, epsilon: 0.05
# episode: 39877/40000, score: 90.0, epsilon: 0.05
# episode: 39878/40000, score: 79.7, epsilon: 0.05
# episode: 39879/40000, score: 94.0, epsilon: 0.05
# episode: 39880/40000, score: 91.9, epsilon: 0.05
# episode: 39881/40000, score: 86.2, epsilon: 0.05
# episode: 39882/40000, score: 91.7, epsilon: 0.05
# episode: 39883/40000, score: 95.9, epsilon: 0.05
# episode: 39884/40000, score: 74.5, epsilon: 0.05
# episode: 39885/40000, score: 91.8, epsilon: 0.05
# episode: 39886/40000, score: 82.8, epsilon: 0.05
# episode: 39887/40000, score: 91.8, epsilon: 0.05
# episode: 39888/40000, score: 89.1, epsilon: 0.05
# episode: 39889/40000, score: 83.4, epsilon: 0.05
# episode: 39890/40000, score: 95.8, epsilon: 0.05
# episode: 39891/40000, score: 90.2, epsilon: 0.05
# episode: 39892/40000, score: 95.1, epsilon: 0.05
# episode: 39893/40000, score: 94.5, epsilon: 0.05
# episode: 39894/40000, score: 83.0, epsilon: 0.05
# episode: 39895/40000, score: 95.4, epsilon: 0.05
# episode: 39896/40000, score: 94.4, epsilon: 0.05
# episode: 39897/40000, score: 0.1, epsilon: 0.05
# episode: 39898/40000, score: 83.3, epsilon: 0.05
# episode: 39899/40000, score: 95.4, epsilon: 0.05
# episode: 39900/40000, score: 93.0, epsilon: 0.05
# episode: 39901/40000, score: 90.7, epsilon: 0.05
# episode: 39902/40000, score: 91.7, epsilon: 0.05
# episode: 39903/40000, score: 76.0, epsilon: 0.05
# episode: 39904/40000, score: 89.1, epsilon: 0.05
# episode: 39905/40000, score: 91.4, epsilon: 0.05
# episode: 39906/40000, score: 79.6, epsilon: 0.05
# episode: 39907/40000, score: 92.4, epsilon: 0.05
# episode: 39908/40000, score: 94.1, epsilon: 0.05
# episode: 39909/40000, score: 94.3, epsilon: 0.05
# episode: 39910/40000, score: 89.4, epsilon: 0.05
# episode: 39911/40000, score: 61.0, epsilon: 0.05
# episode: 39912/40000, score: 95.8, epsilon: 0.05
# episode: 39913/40000, score: 95.8, epsilon: 0.05
# episode: 39914/40000, score: 95.4, epsilon: 0.05
# episode: 39915/40000, score: 94.9, epsilon: 0.05
# episode: 39916/40000, score: 92.1, epsilon: 0.05
# episode: 39917/40000, score: 94.1, epsilon: 0.05
# episode: 39918/40000, score: 94.6, epsilon: 0.05
# episode: 39919/40000, score: 92.6, epsilon: 0.05
# episode: 39920/40000, score: 91.3, epsilon: 0.05
# episode: 39921/40000, score: 91.4, epsilon: 0.05
# episode: 39922/40000, score: 93.5, epsilon: 0.05
# episode: 39923/40000, score: 85.1, epsilon: 0.05
# episode: 39924/40000, score: 93.4, epsilon: 0.05
# episode: 39925/40000, score: 95.7, epsilon: 0.05
# episode: 39926/40000, score: 90.6, epsilon: 0.05
# episode: 39927/40000, score: 95.1, epsilon: 0.05
# episode: 39928/40000, score: 93.5, epsilon: 0.05
# episode: 39929/40000, score: 94.7, epsilon: 0.05
# episode: 39930/40000, score: 93.6, epsilon: 0.05
# episode: 39931/40000, score: 81.3, epsilon: 0.05
# episode: 39932/40000, score: 79.8, epsilon: 0.05
# episode: 39933/40000, score: 96.2, epsilon: 0.05
# episode: 39934/40000, score: 92.1, epsilon: 0.05
# episode: 39935/40000, score: 83.6, epsilon: 0.05
# episode: 39936/40000, score: 93.8, epsilon: 0.05
# episode: 39937/40000, score: 88.9, epsilon: 0.05
# episode: 39938/40000, score: 80.6, epsilon: 0.05
# episode: 39939/40000, score: 84.7, epsilon: 0.05
# episode: 39940/40000, score: 81.7, epsilon: 0.05
# episode: 39941/40000, score: 97.4, epsilon: 0.05
# episode: 39942/40000, score: 88.8, epsilon: 0.05
# episode: 39943/40000, score: 94.3, epsilon: 0.05
# episode: 39944/40000, score: 89.0, epsilon: 0.05
# episode: 39945/40000, score: 93.7, epsilon: 0.05
# episode: 39946/40000, score: 94.5, epsilon: 0.05
# episode: 39947/40000, score: 91.5, epsilon: 0.05
# episode: 39948/40000, score: 93.3, epsilon: 0.05
# episode: 39949/40000, score: 95.4, epsilon: 0.05
# episode: 39950/40000, score: 88.9, epsilon: 0.05
# episode: 39951/40000, score: 93.7, epsilon: 0.05
# episode: 39952/40000, score: 94.7, epsilon: 0.05
# episode: 39953/40000, score: 89.6, epsilon: 0.05
# episode: 39954/40000, score: 95.3, epsilon: 0.05
# episode: 39955/40000, score: 81.1, epsilon: 0.05
# episode: 39956/40000, score: 93.9, epsilon: 0.05
# episode: 39957/40000, score: 91.2, epsilon: 0.05
# episode: 39958/40000, score: 91.4, epsilon: 0.05
# episode: 39959/40000, score: 91.8, epsilon: 0.05
# episode: 39960/40000, score: 91.9, epsilon: 0.05
# episode: 39961/40000, score: 94.7, epsilon: 0.05
# episode: 39962/40000, score: 90.9, epsilon: 0.05
# episode: 39963/40000, score: 94.0, epsilon: 0.05
# episode: 39964/40000, score: 87.8, epsilon: 0.05
# episode: 39965/40000, score: 83.4, epsilon: 0.05
# episode: 39966/40000, score: 92.2, epsilon: 0.05
# episode: 39967/40000, score: 92.5, epsilon: 0.05
# episode: 39968/40000, score: 92.1, epsilon: 0.05
# episode: 39969/40000, score: 91.9, epsilon: 0.05
# episode: 39970/40000, score: 92.9, epsilon: 0.05
# episode: 39971/40000, score: 87.3, epsilon: 0.05
# episode: 39972/40000, score: 73.6, epsilon: 0.05
# episode: 39973/40000, score: 91.7, epsilon: 0.05
# episode: 39974/40000, score: 83.4, epsilon: 0.05
# episode: 39975/40000, score: 91.4, epsilon: 0.05
# episode: 39976/40000, score: 95.5, epsilon: 0.05
# episode: 39977/40000, score: 89.1, epsilon: 0.05
# episode: 39978/40000, score: 89.4, epsilon: 0.05
# episode: 39979/40000, score: 91.0, epsilon: 0.05
# episode: 39980/40000, score: 93.5, epsilon: 0.05
# episode: 39981/40000, score: 93.2, epsilon: 0.05
# episode: 39982/40000, score: 78.6, epsilon: 0.05
# episode: 39983/40000, score: 93.0, epsilon: 0.05
# episode: 39984/40000, score: 91.0, epsilon: 0.05
# episode: 39985/40000, score: 93.3, epsilon: 0.05
# episode: 39986/40000, score: 92.5, epsilon: 0.05
# episode: 39987/40000, score: 94.8, epsilon: 0.05
# episode: 39988/40000, score: 65.6, epsilon: 0.05
# episode: 39989/40000, score: 61.9, epsilon: 0.05
# episode: 39990/40000, score: 90.2, epsilon: 0.05
# episode: 39991/40000, score: 94.7, epsilon: 0.05
# episode: 39992/40000, score: 91.0, epsilon: 0.05
# episode: 39993/40000, score: 93.9, epsilon: 0.05
# episode: 39994/40000, score: 78.5, epsilon: 0.05
# episode: 39995/40000, score: 84.3, epsilon: 0.05
# episode: 39996/40000, score: 15.3, epsilon: 0.05
# episode: 39997/40000, score: 10.2, epsilon: 0.05
# episode: 39998/40000, score: 95.7, epsilon: 0.05
# episode: 39999/40000, score: 95.3, epsilon: 0.05

# %%
episodes = [n for n in range(len(score))]
plt.scatter(episodes,score, s = 1)
#plt.ylim([-1000,0])
print("Training on {} asymmetries in the range : {}".format(env.N_asymmetries,env.asymmetries))
print("Available actions: \n{}".format(env.action_space))
print("T_max = {}, Number of steps = {}, dt = {}".format(env.t_max, env.N_alfa, env.alfa_dt))
print("Hyperparameters: memorysize = {}, tau = {}, batch_size = {}".format(len(agent.memory),tau, batch_size))
print("Total number of experiences = {}".format(env.N_alfa*n_episodes))
print("Reward distribution: {}".format(np.around(env.reward_distribution,2)))
# Out:
# Training on 6 asymmetries in the range : [0.53, 0.532, 0.534, 0.536, 0.538, 0.54]
# Available actions:
# [-10240  -5120  -2560  -1280   -640   -320   -160    -80    -40    -20
#       0     20     40     80    160    320    640   1280   2560   5120
#   10240]
# T_max = 5, Number of steps = 50, dt = 0.1
# Hyperparameters: memorysize = 200000, tau = 0.001, batch_size = 32
# Total number of experiences = 2000000
# Reward distribution: [1. 1. 1. 1. 1. 1.]

# %% [markdown]
# ## Load earlier instances of the agent, and find its best solution

# %%
loaded_agent = DQNAgent(state_size, action_size)
loaded_agent.model.load_weights('model_output/Model_1/weights_10000.hdf5')

state = env.reset()
state = np.reshape(state, [1,state_size])
loaded_agent.epsilon = 0.0

for t in range(env.N_alfa):

    action = loaded_agent.act(state)

    next_state, reward, done, _ = env.step(action)

    next_state = np.reshape(next_state, [1,state_size])

    state = next_state

# %%
plt.plot(env.protocol)

# %%
state = env.reset()
state = np.reshape(state, [1,state_size])
agent.epsilon = 0.0

for t in range(env.N_alfa):

    action = agent.act(state)

    next_state, reward, done, _ = env.step(action)

    next_state = np.reshape(next_state, [1,state_size])

    state = next_state

# %% [markdown]
# # Testing on different asymmetries

# %%
protocol = env.protocol

N = env.N_asymmetries
asymmetries = env.asymmetries

leakage = [0 for n in range (N)]
asymmetry = [0 for n in range (N)]
punishment = [0 for n in range (N)]
C_array = [0 for n in range (N)]

for n in range (N):
    print(asymmetries[n])
    interp_energy, interp_overlap = interp_generator(asymmetries[n])
    
    C_array[n],leakage[n], punishment[n] = interp_reward(0.05,1000,protocol)
  
plt.plot(asymmetries,punishment)
# Out:
# 0.53
# 0.532
# 0.534
# 0.536
# 0.538
# 0.54

# %%
plt.plot(asymmetries,leakage)
plt.plot(asymmetries,punishment)

# %%
for n in range(N):
    
    plt.scatter(asymmetries[n],abs(C_array[n][0])**2, color = 'red')
    plt.scatter(asymmetries[n],abs(C_array[n][1])**2, color = 'blue')
    plt.scatter(asymmetries[n],sum(abs(C_array[n][2:])**2), color = 'green')

# %%
def interp_reward(sigma, N_t, protocol):

        time = np.array([ n*env.alfa_dt for n in range (env.N_alfa+1) ])
        alfa_interp = interp1d( time,protocol, kind = 'cubic')

        time = np.linspace(0,env.t_max,N_t)
        alfa = alfa_interp(time)
        alfa = np.clip(alfa,0,5000)
        dt = time[1]-time[0]
        max_lvl = env.max_lvl
 
        E = []
        for t in range(N_t):
            E.append([interp_energy[n](alfa[t]) for n in range(max_lvl)])
        E = np.array(E)
        
        phi = []
        for t in range(N_t):
                integral = [np.trapz(x=time[0:t+1], y= E[0:t+1,n]) for n in range(max_lvl)]
                phi.append(integral)  
        phi = np.array(phi)   

        def interaction_int(n, alfa_in, f = []):
            test = sum([interp_overlap[n][m](abs(alfa_in))*np.exp(1j*(phi[t,n] - phi[t,m]) )*f[m] for m in range(max_lvl) if m != n ])*dalfa
            return test

        C = np.array([ 0 for n in range(max_lvl) ])
        C[0] = 1
        C_new = np.array( [ 0 for n in range(max_lvl) ])
        C_t = []
        C_t.append(C)

        for t in range(N_t -1):
            
            dalfa = (alfa[t+1] - alfa[t])/dt

            k1 = np.array([dt*interaction_int(n, alfa[t], C ) for n in range(max_lvl)])
            k2 = np.array([dt*interaction_int(n, alfa[t]+ dalfa*dt/2, C + k1/2 ) for n in range(max_lvl)])
            k3 = np.array([dt*interaction_int(n, alfa[t]+ dalfa*dt/2, C + k2/2 ) for n in range(max_lvl)])
            k4 = np.array([dt*interaction_int(n, alfa[t]+ dalfa*dt, C + k3) for n in range(max_lvl)])

            C_new = C + (k1 + 2*k2 + 2*k3 + k4)/6

            C = C_new

            C_t.append(C)

        #C_t = np.array(C_t)

        c1 = abs(C[0])**2
        c2 = abs(C[1])**2

        leakage = sum( abs(C[n])**2 for n in range(2,max_lvl) )
        reward = np.exp( -((c1-0.5)**2 + (c2-0.5)**2)/(sigma))
        
        #print("Normalization_int: {}" .format(sum(abs(C)**2)))
        #print(abs(C)**2)
        #plt.plot(alfa(time),abs(np.array(C_t))**2)
        #plt.plot(time,abs(alfa(time)))
        plt.plot(time,alfa)
        return C, leakage, reward

# %%
def interp_generator(a):
    
    max_lvl = 4 

    tab_alfa = np.loadtxt('/home/vegard/Split-wavefunction/data/alfa/alfa_a_' + "{:.3f}".format(a) + '.txt', delimiter = ',')        
    energies = np.loadtxt('/home/vegard/Split-wavefunction/data/energies/Energies_a_' + "{:.3f}".format(a) + '.txt', delimiter = ',')
    overlap = np.loadtxt('/home/vegard/Split-wavefunction/data/overlap/overlap_a_' + "{:.3f}".format(a)+ '.txt', delimiter = ',')

    overlap = np.reshape(overlap, [max_lvl,max_lvl,5001], order = 'F')


    interp_energy = [None]*max_lvl

    for n in range(max_lvl):
        f = interp1d(tab_alfa,energies[:,n], kind = 'cubic')
        interp_energy[n] = f

    interp_overlap = [[0] * max_lvl for i in range(max_lvl)]

    for n in range(max_lvl):
        for m in range(max_lvl):
            interp_overlap[n][m] = interp1d(tab_alfa,overlap[n,m,:], kind = 'cubic')
    
    return interp_energy, interp_overlap

# %% [markdown]
# # Plot Q function

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
loaded_agent = DQNAgent(state_size, action_size)
loaded_agent.epsilon = 0.0
loaded_agent.model.load_weights(output_dir+'weights_1000.hdf5')

# %%
Q_protocol = []
Q_alfa = 0
Q_time = []

Q_protocol.append(0)
Q_time.append(0)

for t in range (env.N_alfa):
    
    time = (t+1)*env.alfa_dt
    
    state = np.array([Q_alfa/env.max_alfa,time/env.t_max])
    state = np.reshape(state, [1,state_size])
    max_arg = np.argmax(loaded_agent.model.predict(state)) 
    #print("action: {}".format(max_arg))
    Q_alfa += env.action_space[max_arg]*env.alfa_dt
    #print("suggest: {}".format(Q_alfa))
    Q_alfa = np.clip(Q_alfa,0,env.max_alfa)
    #print("actual: {}".format(Q_alfa))
    
    Q_time.append(time)
    Q_protocol.append(Q_alfa)

plt.plot(Q_time,Q_protocol)

# %%
t_max = env.t_max
max_alfa = env.max_alfa

N_a = 50
N_t = 50

Q_max = np.ndarray(shape=(N_t,N_a),buffer = np.zeros(N_t*N_a))
Q_max_arg = np.ndarray(shape=(N_t,N_a),buffer = np.zeros(N_t*N_a))

time = np.linspace(0,t_max,N_t)
alfa = np.linspace(0,max_alfa,N_a)

alfa_time = np.arange(0,env.t_max,env.alfa_dt)
max_protocol = alfa_time*env.action_space[-1]
max_protocol = np.clip(max_protocol, 0, env.max_alfa)

for t in range (N_t):
    
    for a in range(N_a):        
        
        state = np.array([alfa[a]/max_alfa,time[t]/t_max])
        state = np.reshape(state, [1,state_size])

        Q_max_arg[t,a] = np.argmax(loaded_agent.model.predict(state))
        Q_max[t,a] = np.max(loaded_agent.model.predict(state))

# %%
X,Y = np.meshgrid(time, alfa)

Z = Q_max_arg - len(env.action_space)/2

fig, ax = plt.subplots()


p = ax.pcolor(X, Y, Z)
cb = fig.colorbar(p)

plt.plot(alfa_time,max_protocol , color='red')
plt.plot(Q_time,Q_protocol, 'o-', color ='red')

# %%
X,Y = np.meshgrid(time, alfa)

Z = Q_max

fig, ax = plt.subplots()

p = ax.pcolor(X, Y, Z, vmin=Z.min(), vmax=Z.max())
cb = fig.colorbar(p)

plt.plot(alfa_time,max_protocol , color='black')
plt.plot(Q_time,Q_protocol, 'o-', color ='red')
